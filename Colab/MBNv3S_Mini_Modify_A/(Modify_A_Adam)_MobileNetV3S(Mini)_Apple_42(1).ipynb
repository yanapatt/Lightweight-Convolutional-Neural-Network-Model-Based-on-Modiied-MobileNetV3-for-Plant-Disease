# %% [markdown]
# #**Benchmark**

# %% [markdown]
# #**Section 1: Import Important Library**

# %%
import warnings
warnings.filterwarnings('ignore')

from datetime import datetime
import pytz
from time import time

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import font_manager
import seaborn as sns
import itertools
import psutil

import cv2
import shutil
import PIL
import os
from pathlib import Path
import sys

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize, LabelEncoder, LabelBinarizer

import random as rd
import numpy as np
import zipfile

# %%
import tensorflow as tf
os.environ["KERAS_BACKEND"] = "tensorflow"
import keras

# %%
from google.colab import drive
drive.mount('/content/drive')

sys.path.append('/content/drive/MyDrive/projectPlant/Colab')
from my_model import *
from helper_functions import *
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Detail of Python Notebook in Google Colab**

# %%
# !nvidia-smi

import subprocess
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {tf.keras.__version__}")
print("-------------------------------------------------------------")
print(f"Python {sys.version}")
print("-------------------------------------------------------------")

# ตรวจสอบ GPU
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("Running on GPU")
    strategy = tf.distribute.MirroredStrategy()
    print(f"Number of GPUs Available: {len(gpus)}")

    # ดึงข้อมูล GPU Memory
    try:
        result = subprocess.run(
            ['nvidia-smi', '--query-gpu=memory.total', '--format=csv,noheader,nounits'],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )
        gpu_memory = result.stdout.strip().split('\n')
        for idx, mem in enumerate(gpu_memory):
            print(f"GPU {idx}: Total Memory: {int(mem) / 1024:.2f} GB")
    except FileNotFoundError:
        print("nvidia-smi is not available on this system.")
else:
    print("No GPU detected. Running on CPU")
    strategy = tf.distribute.get_strategy()

# แสดงจำนวนอุปกรณ์ที่พร้อมใช้งาน
print("Number of replicas:", strategy.num_replicas_in_sync)
print("-------------------------------------------------------------")

# แสดงจำนวน RAM ทั้งหมด
total_ram = psutil.virtual_memory().total / (1024 ** 3)
print(f"Total RAM of Colab instance: {total_ram:.2f} GB")
print("-------------------------------------------------------------")

# แสดงเวลาปัจจุบันในเขตเวลาไทย
thailand_tz = pytz.timezone('Asia/Bangkok')
current_time = datetime.now(thailand_tz).strftime("%Y-%m-%d %H:%M:%S")
print("Current Time (Thailand):", current_time)
# Out:
# Sun Aug 24 14:47:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Tensorflow version: 2.19.0
# Keras version: 3.10.0
# -------------------------------------------------------------
# Python 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# -------------------------------------------------------------
# Running on GPU
# Number of GPUs Available: 1
# GPU 0: Total Memory: 15.00 GB
# Number of replicas: 1
# -------------------------------------------------------------
# Total RAM of Colab instance: 12.67 GB
# -------------------------------------------------------------
# Current Time (Thailand): 2025-08-24 21:47:25

# %% [markdown]
# **Initialize Setting (Focus First)**

# %%
SEED=42
np.random.seed(SEED)
tf.random.set_seed(SEED)
rd.seed(SEED)
BATCH_SIZE = 64

# %%
root_dir = '/content/drive/MyDrive/projectPlant/'
title = 'Apple Dataset'
dataset_name = 'appleDataset'
dataset_dir = root_dir + dataset_name

# %%
current_dir = os.getcwd()

# %%
zip_filename = 'apple_dataset_raw.zip'
zip_dir = dataset_dir + '/' + zip_filename

with zipfile.ZipFile(zip_dir, 'r') as zip_ref: # แตกไฟล์จาก G-Drive มาที่ Runtime Directory
    zip_ref.extractall(current_dir)
print(f"Unzip complete at {current_dir}")
# Out:
# Unzip complete at /content

# %%
locations = [f"{root_dir}Extra2/Font"]
font_files = font_manager.findSystemFonts(fontpaths=locations)
print(font_files[0])
for file in font_files:
  font_manager.fontManager.addfont(file)
# Out:
# /content/drive/MyDrive/projectPlant/Extra2/Font/OPTITimes-Roman.otf

# %% [markdown]
# #**Section 2: Load Dataset**

# %%
model_name = 'MBNv3Small_Mini_Modify_A'
otmz_name = 'Adam'
seed_num = f"{SEED}"
rounds_num = '1'

# %%
img_dir = root_dir + 'Extra2/' + dataset_name
sample_img_dir = img_dir + '/SampleImages'
img_each_model_dir = img_dir + '/' + model_name + '_' + dataset_name + '_' + otmz_name + '_' + seed_num + '(' + rounds_num + ')'
excel_dir = root_dir + 'DatasetSetting/' + dataset_name + '/' + 'split_data_seed_' + seed_num + '.xlsx'

# %%
os.makedirs(img_dir, exist_ok=True)
os.makedirs(sample_img_dir, exist_ok=True)
os.makedirs(img_each_model_dir, exist_ok=True)

# %% [markdown]
# #**Section 3: Placing data into a Dataframe**

# %% [markdown]
# ##**Convert to dataframe**

# %%
TRAIN_DF, VALID_DF, TEST_DF = to_dataframe_excel(path=excel_dir, sheet_name='Split-Data', mode='single', condition=False, labels_mapping=None)

# %%
print(f"Train Dataframe\n")
print(f"Total images: {len(TRAIN_DF)}")
print(f"Total classes: {TRAIN_DF['Label'].nunique()}")
TRAIN_DF
# Out:
# Train Dataframe
#
# Total images: 1164
# Total classes: 4
#                                                Filepath    Label  \
# 0     /content/drive/MyDrive/projectPlant/appleDatas...  healthy
# 1     /content/drive/MyDrive/projectPlant/appleDatas...     scab
# 2     /content/drive/MyDrive/projectPlant/appleDatas...     rust
# 3     /content/drive/MyDrive/projectPlant/appleDatas...     rust
# 4     /content/drive/MyDrive/projectPlant/appleDatas...     rust
# ...                                                 ...      ...
# 1159  /content/drive/MyDrive/projectPlant/appleDatas...  healthy
# 1160  /content/drive/MyDrive/projectPlant/appleDatas...     scab
# 1161  /content/drive/MyDrive/projectPlant/appleDatas...  healthy
# 1162  /content/drive/MyDrive/projectPlant/appleDatas...     rust
# 1163  /content/drive/MyDrive/projectPlant/appleDatas...     scab
#
#       Original_Index
# 0                352
# 1                612
# 2               1214
# 3               1350
# 4               1474
# ...              ...
# 1159             216
# 1160             995
# 1161              33
# 1162            1218
# 1163             897
#
# [1164 rows x 3 columns]

# %%
TRAIN_DF["Filepath"] = TRAIN_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
TRAIN_DF
# Out:
#                                           Filepath    Label  Original_Index
# 0     /content/appleDataset/healthy/Train_1605.jpg  healthy             352
# 1           /content/appleDataset/scab/Train_7.jpg     scab             612
# 2         /content/appleDataset/rust/Train_971.jpg     rust            1214
# 3         /content/appleDataset/rust/Train_571.jpg     rust            1350
# 4         /content/appleDataset/rust/Train_313.jpg     rust            1474
# ...                                            ...      ...             ...
# 1159   /content/appleDataset/healthy/Train_348.jpg  healthy             216
# 1160     /content/appleDataset/scab/Train_1346.jpg     scab             995
# 1161   /content/appleDataset/healthy/Train_901.jpg  healthy              33
# 1162      /content/appleDataset/rust/Train_957.jpg     rust            1218
# 1163      /content/appleDataset/scab/Train_158.jpg     scab             897
#
# [1164 rows x 3 columns]

# %%
print(f"Validation Dataframe\n")
print(f"Total images: {len(VALID_DF)}")
print(f"Total classes: {VALID_DF['Label'].nunique()}")
VALID_DF
# Out:
# Validation Dataframe
#
# Total images: 292
# Total classes: 4
#                                               Filepath             Label  \
# 0    /content/drive/MyDrive/projectPlant/appleDatas...           healthy
# 1    /content/drive/MyDrive/projectPlant/appleDatas...           healthy
# 2    /content/drive/MyDrive/projectPlant/appleDatas...              rust
# 3    /content/drive/MyDrive/projectPlant/appleDatas...           healthy
# 4    /content/drive/MyDrive/projectPlant/appleDatas...              scab
# ..                                                 ...               ...
# 287  /content/drive/MyDrive/projectPlant/appleDatas...           healthy
# 288  /content/drive/MyDrive/projectPlant/appleDatas...           healthy
# 289  /content/drive/MyDrive/projectPlant/appleDatas...  multiple_disease
# 290  /content/drive/MyDrive/projectPlant/appleDatas...              scab
# 291  /content/drive/MyDrive/projectPlant/appleDatas...  multiple_disease
#
#      Original_Index
# 0               406
# 1               262
# 2              1460
# 3               377
# 4               629
# ..              ...
# 287             110
# 288              57
# 289            1179
# 290             692
# 291            1129
#
# [292 rows x 3 columns]

# %%
VALID_DF["Filepath"] = VALID_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
VALID_DF
# Out:
#                                               Filepath             Label  \
# 0         /content/appleDataset/healthy/Train_1391.jpg           healthy
# 1         /content/appleDataset/healthy/Train_1012.jpg           healthy
# 2             /content/appleDataset/rust/Train_347.jpg              rust
# 3         /content/appleDataset/healthy/Train_1530.jpg           healthy
# 4             /content/appleDataset/scab/Train_638.jpg              scab
# ..                                                 ...               ...
# 287        /content/appleDataset/healthy/Train_675.jpg           healthy
# 288        /content/appleDataset/healthy/Train_826.jpg           healthy
# 289  /content/appleDataset/multiple_disease/Train_4...  multiple_disease
# 290           /content/appleDataset/scab/Train_429.jpg              scab
# 291  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
#
#      Original_Index
# 0               406
# 1               262
# 2              1460
# 3               377
# 4               629
# ..              ...
# 287             110
# 288              57
# 289            1179
# 290             692
# 291            1129
#
# [292 rows x 3 columns]

# %%
print(f"Test Dataframe\n")
print(f"Total images: {len(TEST_DF)}")
print(f"Total classes: {TEST_DF['Label'].nunique()}")
TEST_DF
# Out:
# Test Dataframe
#
# Total images: 365
# Total classes: 4
#                                               Filepath             Label  \
# 0    /content/drive/MyDrive/projectPlant/appleDatas...              rust
# 1    /content/drive/MyDrive/projectPlant/appleDatas...           healthy
# 2    /content/drive/MyDrive/projectPlant/appleDatas...              rust
# 3    /content/drive/MyDrive/projectPlant/appleDatas...              rust
# 4    /content/drive/MyDrive/projectPlant/appleDatas...              rust
# ..                                                 ...               ...
# 360  /content/drive/MyDrive/projectPlant/appleDatas...              rust
# 361  /content/drive/MyDrive/projectPlant/appleDatas...           healthy
# 362  /content/drive/MyDrive/projectPlant/appleDatas...           healthy
# 363  /content/drive/MyDrive/projectPlant/appleDatas...  multiple_disease
# 364  /content/drive/MyDrive/projectPlant/appleDatas...              rust
#
#      Original_Index
# 0              1457
# 1               102
# 2              1585
# 3              1659
# 4              1375
# ..              ...
# 360            1514
# 361             214
# 362             471
# 363            1151
# 364            1648
#
# [365 rows x 3 columns]

# %%
TEST_DF["Filepath"] = TEST_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
TEST_DF
# Out:
#                                               Filepath             Label  \
# 0             /content/appleDataset/rust/Train_328.jpg              rust
# 1           /content/appleDataset/healthy/Train_68.jpg           healthy
# 2            /content/appleDataset/rust/Train_1624.jpg              rust
# 3            /content/appleDataset/rust/Train_1400.jpg              rust
# 4             /content/appleDataset/rust/Train_542.jpg              rust
# ..                                                 ...               ...
# 360          /content/appleDataset/rust/Train_1813.jpg              rust
# 361        /content/appleDataset/healthy/Train_383.jpg           healthy
# 362       /content/appleDataset/healthy/Train_1186.jpg           healthy
# 363  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 364          /content/appleDataset/rust/Train_1461.jpg              rust
#
#      Original_Index
# 0              1457
# 1               102
# 2              1585
# 3              1659
# 4              1375
# ..              ...
# 360            1514
# 361             214
# 362             471
# 363            1151
# 364            1648
#
# [365 rows x 3 columns]

# %% [markdown]
# #**Section 4: Data Preparing**

# %%
IMAGE_SIZE = (224, 224)
IMAGE_SHAPE = (224, 224, 3)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=keras.applications.mobilenet_v3.preprocess_input,
    horizontal_flip=True,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    brightness_range=[0.9, 1.1],
    fill_mode='nearest'
)

valid_test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=keras.applications.mobilenet_v3.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe = TRAIN_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed = SEED
)

val_images = valid_test_generator.flow_from_dataframe(
    dataframe = VALID_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed = SEED
)

test_images = valid_test_generator.flow_from_dataframe(
    dataframe = TEST_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = False
)
# Out:
# Found 1164 validated image filenames belonging to 4 classes.
# Found 292 validated image filenames belonging to 4 classes.
# Found 365 validated image filenames belonging to 4 classes.

# %% [markdown]
# #**Section 5: Preparing the Model**

# %%
checkpoint_path, save_path_h5, save_path_keras, save_path_json, save_path_history, save_path_tensorboard = save_path(otmz_name=otmz_name, dataset_name=dataset_name, rounds=rounds_num, model=model_name, seed=SEED)
print("Recheck save path: \n")
print(f"Checkpoint path: {checkpoint_path}")
print(f"Save path h5: {save_path_h5}")
print(f"Save path keras: {save_path_keras}")
print(f"Save path json: {save_path_json}")
print(f"Save path history: {save_path_history}")
print(f"Save path tensorboard: {save_path_tensorboard}")
# Out:
# Recheck save path:
#
# Checkpoint path: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# Save path h5: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1).h5
# Save path keras: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1).keras
# Save path json: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1).json
# Save path history: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1).csv
# Save path tensorboard: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_tensorboard_logs

# %% [markdown]
# ##**Create Model Callback**

# %%
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_path,
    monitor = 'val_accuracy',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False,
    mode = 'auto'
)

class LearningRateTracker(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        # Access learning rate through learning_rate property
        lr = self.model.optimizer.learning_rate.numpy()  # This will now work correctly
        logs = logs or {}
        logs['lr'] = lr

        if not hasattr(self, 'learning_rates'):
            self.learning_rates = []
        self.learning_rates.append(lr)

# Create the callback instance
lr_tracker = LearningRateTracker()

tensorlog = keras.callbacks.TensorBoard(
    log_dir = save_path_tensorboard,
    histogram_freq = 1,
    write_graph = True,
    write_images = True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor = 'val_loss',
    factor = 0.1,
    patience = 5,
    verbose = 1,
    min_lr = 1e-06
)

# %% [markdown]
# ##**Model Parameters**

# %%
chao_kuay_model = build_model(model_name="MobileNetV3SmallMinimalistic_Modify_A", input_shape=IMAGE_SHAPE, num_classes=len(train_images.class_indices))
chao_kuay_model.compile(
    optimizer = keras.optimizers.Adam(
        learning_rate = 1e-04,
        beta_1 = 0.9,
        beta_2 = 0.999,
        epsilon = 1e-07,
        name = 'Adam'
    ),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
chao_kuay_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_minimalistic_224_1.0_float_no_top_v2.h5
# 2128592/2128592 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 113, 113,  │          0 │ re_lu[0][0]       │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 56, 56,    │        144 │ expanded_conv_de… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 56, 56,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 56, 56,    │        256 │ re_lu_1[0][0]     │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 56, 56,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 56, 56,    │      1,152 │ expanded_conv_pr… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 56, 56,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 57, 57,    │          0 │ re_lu_2[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 28, 28,    │        648 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 28, 28,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 28, 28,    │      1,728 │ re_lu_3[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 28, 28,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 28, 28,    │      2,112 │ expanded_conv_1_… │
# │ (Conv2D)            │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 28, 28,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 28, 28,    │        792 │ re_lu_4[0][0]     │
# │ (DepthwiseConv2D)   │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 28, 28,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 28, 28,    │      2,112 │ re_lu_5[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 28, 28,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 28, 28,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 28, 28,    │      2,304 │ expanded_conv_2_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 28, 28,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 29, 29,    │          0 │ re_lu_6[0][0]     │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 14, 14,    │        864 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 14, 14,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 14, 14,    │          0 │ expanded_conv_3_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 14, 14,    │      3,840 │ re_lu_7[0][0]     │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 14, 14,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 14, 14,    │      9,600 │ expanded_conv_3_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 14, 14,    │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │                     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 14, 14,    │      2,160 │ re_lu_8[0][0]     │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 14, 14,    │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │                     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 14, 14,    │      9,600 │ re_lu_9[0][0]     │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 14, 14,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 14, 14,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 14, 14,    │      9,600 │ expanded_conv_4_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 14, 14,    │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_5_… │
# │                     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 14, 14,    │      2,160 │ re_lu_10[0][0]    │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 14, 14,    │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_5_… │
# │                     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 14, 14,    │      9,600 │ re_lu_11[0][0]    │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 14, 14,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 14, 14,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 14, 14,    │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      1,080 │ re_lu_12[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │      5,760 │ re_lu_13[0][0]    │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        192 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │      6,912 │ expanded_conv_6_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,296 │ re_lu_14[0][0]    │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │      6,912 │ re_lu_15[0][0]    │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        192 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 48)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     13,824 │ expanded_conv_7_… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │                     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 15, 15,    │          0 │ re_lu_16[0][0]    │
# │ (ZeroPadding2D)     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │      2,592 │ expanded_conv_8_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 7, 7, 288) │          0 │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_1_project │ (None, 7, 7, 96)  │     27,648 │ re_lu_23[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_1_projec… │ (None, 7, 7, 96)  │        384 │ sandglass_1_proj… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_1_expand  │ (None, 7, 7, 288) │     27,648 │ sandglass_1_proj… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_1_expand… │ (None, 7, 7, 288) │      1,152 │ sandglass_1_expa… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 7, 7, 288) │          0 │ sandglass_1_expa… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_1_depthw… │ (None, 7, 7, 288) │      2,592 │ re_lu_24[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_1_depthw… │ (None, 7, 7, 288) │      1,152 │ sandglass_1_dept… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_1_add     │ (None, 7, 7, 288) │          0 │ expanded_conv_8_… │
# │ (Add)               │                   │            │ sandglass_1_dept… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_2_depthw… │ (None, 7, 7, 288) │      2,592 │ sandglass_1_add[… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_2_depthw… │ (None, 7, 7, 288) │      1,152 │ sandglass_2_dept… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 7, 7, 288) │          0 │ sandglass_2_dept… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_2_project │ (None, 7, 7, 96)  │     27,648 │ re_lu_25[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_2_projec… │ (None, 7, 7, 96)  │        384 │ sandglass_2_proj… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_2_expand  │ (None, 7, 7, 576) │     55,296 │ sandglass_2_proj… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_2_expand… │ (None, 7, 7, 576) │      2,304 │ sandglass_2_expa… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 7, 7, 576) │          0 │ sandglass_2_expa… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_2_depthw… │ (None, 7, 7, 576) │      5,184 │ re_lu_26[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_2_depthw… │ (None, 7, 7, 576) │      2,304 │ sandglass_2_dept… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_depthw… │ (None, 7, 7, 576) │      5,184 │ sandglass_2_dept… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_depthw… │ (None, 7, 7, 576) │      2,304 │ sandglass_3_dept… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 7, 7, 576) │          0 │ sandglass_3_dept… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_project │ (None, 7, 7, 96)  │     55,296 │ re_lu_27[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_projec… │ (None, 7, 7, 96)  │        384 │ sandglass_3_proj… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_expand  │ (None, 7, 7, 576) │     55,296 │ sandglass_3_proj… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_expand… │ (None, 7, 7, 576) │      2,304 │ sandglass_3_expa… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_28 (ReLU)     │ (None, 7, 7, 576) │          0 │ sandglass_3_expa… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_depthw… │ (None, 7, 7, 576) │      5,184 │ re_lu_28[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_depthw… │ (None, 7, 7, 576) │      2,304 │ sandglass_3_dept… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sandglass_3_add     │ (None, 7, 7, 576) │          0 │ sandglass_2_dept… │
# │ (Add)               │                   │            │ sandglass_3_dept… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 576)       │          0 │ sandglass_3_add[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Predictions (Dense) │ (None, 4)         │      2,308 │ avg_pool[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 401,836 (1.53 MB)
#  Trainable params: 279,940 (1.07 MB)
#  Non-trainable params: 121,896 (476.16 KB)

# %% [markdown]
# #**Section 6: Training the model**

# %%
start_time_training = time()

history = chao_kuay_model.fit(
    x = train_images,
    validation_data = val_images,
    batch_size = BATCH_SIZE,
    callbacks = [model_checkpoint, tensorlog, lr_tracker, reduce_lr],
    epochs = 30,
)

end_time_training = time()
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3542 - loss: 1.3059
# Epoch 1: val_accuracy improved from -inf to 0.32534, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.3593 - loss: 1.3022 - val_accuracy: 0.3253 - val_loss: 1.3608 - learning_rate: 1.0000e-04
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6284 - loss: 1.0138
# Epoch 2: val_accuracy did not improve from 0.32534
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.6300 - loss: 1.0108 - val_accuracy: 0.3253 - val_loss: 1.3706 - learning_rate: 1.0000e-04
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7084 - loss: 0.8238
# Epoch 3: val_accuracy improved from 0.32534 to 0.40068, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.7088 - loss: 0.8225 - val_accuracy: 0.4007 - val_loss: 1.2271 - learning_rate: 1.0000e-04
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7370 - loss: 0.7278
# Epoch 4: val_accuracy improved from 0.40068 to 0.77740, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.7376 - loss: 0.7270 - val_accuracy: 0.7774 - val_loss: 0.6669 - learning_rate: 1.0000e-04
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8011 - loss: 0.6405
# Epoch 5: val_accuracy did not improve from 0.77740
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8007 - loss: 0.6401 - val_accuracy: 0.7603 - val_loss: 0.5936 - learning_rate: 1.0000e-04
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8044 - loss: 0.5573
# Epoch 6: val_accuracy improved from 0.77740 to 0.79110, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8042 - loss: 0.5574 - val_accuracy: 0.7911 - val_loss: 0.5657 - learning_rate: 1.0000e-04
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8062 - loss: 0.5241
# Epoch 7: val_accuracy improved from 0.79110 to 0.82877, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8060 - loss: 0.5248 - val_accuracy: 0.8288 - val_loss: 0.5202 - learning_rate: 1.0000e-04
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8187 - loss: 0.5471
# Epoch 8: val_accuracy did not improve from 0.82877
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8185 - loss: 0.5469 - val_accuracy: 0.8253 - val_loss: 0.5273 - learning_rate: 1.0000e-04
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8321 - loss: 0.4729
# Epoch 9: val_accuracy improved from 0.82877 to 0.85616, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8315 - loss: 0.4737 - val_accuracy: 0.8562 - val_loss: 0.5015 - learning_rate: 1.0000e-04
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8401 - loss: 0.4778
# Epoch 10: val_accuracy did not improve from 0.85616
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8401 - loss: 0.4770 - val_accuracy: 0.8562 - val_loss: 0.4700 - learning_rate: 1.0000e-04
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8543 - loss: 0.4318
# Epoch 11: val_accuracy improved from 0.85616 to 0.85959, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8540 - loss: 0.4320 - val_accuracy: 0.8596 - val_loss: 0.4745 - learning_rate: 1.0000e-04
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8413 - loss: 0.4591
# Epoch 12: val_accuracy did not improve from 0.85959
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.8414 - loss: 0.4582 - val_accuracy: 0.8425 - val_loss: 0.4620 - learning_rate: 1.0000e-04
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8451 - loss: 0.4434
# Epoch 13: val_accuracy did not improve from 0.85959
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8455 - loss: 0.4415 - val_accuracy: 0.8425 - val_loss: 0.4755 - learning_rate: 1.0000e-04
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8447 - loss: 0.4169
# Epoch 14: val_accuracy improved from 0.85959 to 0.86301, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8455 - loss: 0.4160 - val_accuracy: 0.8630 - val_loss: 0.4374 - learning_rate: 1.0000e-04
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8523 - loss: 0.4326
# Epoch 15: val_accuracy did not improve from 0.86301
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8528 - loss: 0.4310 - val_accuracy: 0.8596 - val_loss: 0.4283 - learning_rate: 1.0000e-04
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8572 - loss: 0.3965
# Epoch 16: val_accuracy did not improve from 0.86301
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8572 - loss: 0.3969 - val_accuracy: 0.8527 - val_loss: 0.4170 - learning_rate: 1.0000e-04
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8659 - loss: 0.3779
# Epoch 17: val_accuracy did not improve from 0.86301
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8659 - loss: 0.3775 - val_accuracy: 0.8459 - val_loss: 0.4499 - learning_rate: 1.0000e-04
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8847 - loss: 0.3460
# Epoch 18: val_accuracy improved from 0.86301 to 0.86986, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8844 - loss: 0.3456 - val_accuracy: 0.8699 - val_loss: 0.4169 - learning_rate: 1.0000e-04
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8772 - loss: 0.3505
# Epoch 19: val_accuracy improved from 0.86986 to 0.87671, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1)_best.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8772 - loss: 0.3513 - val_accuracy: 0.8767 - val_loss: 0.4297 - learning_rate: 1.0000e-04
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8886 - loss: 0.3246
# Epoch 20: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8882 - loss: 0.3248 - val_accuracy: 0.8630 - val_loss: 0.4300 - learning_rate: 1.0000e-04
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8970 - loss: 0.2894
# Epoch 21: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8960 - loss: 0.2910 - val_accuracy: 0.8733 - val_loss: 0.4296 - learning_rate: 1.0000e-04
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8944 - loss: 0.2874
# Epoch 22: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8938 - loss: 0.2894 - val_accuracy: 0.8630 - val_loss: 0.4397 - learning_rate: 1.0000e-04
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8783 - loss: 0.3399
# Epoch 23: val_accuracy did not improve from 0.87671
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8787 - loss: 0.3391 - val_accuracy: 0.8527 - val_loss: 0.4412 - learning_rate: 1.0000e-04
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9015 - loss: 0.2918
# Epoch 24: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9014 - loss: 0.2923 - val_accuracy: 0.8527 - val_loss: 0.4401 - learning_rate: 1.0000e-05
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8841 - loss: 0.3702
# Epoch 25: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8844 - loss: 0.3678 - val_accuracy: 0.8664 - val_loss: 0.4377 - learning_rate: 1.0000e-05
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8959 - loss: 0.3046
# Epoch 26: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8955 - loss: 0.3043 - val_accuracy: 0.8699 - val_loss: 0.4349 - learning_rate: 1.0000e-05
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8853 - loss: 0.2999
# Epoch 27: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8854 - loss: 0.3009 - val_accuracy: 0.8664 - val_loss: 0.4356 - learning_rate: 1.0000e-05
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8920 - loss: 0.3211
# Epoch 28: val_accuracy did not improve from 0.87671
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1e-06.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8922 - loss: 0.3208 - val_accuracy: 0.8630 - val_loss: 0.4283 - learning_rate: 1.0000e-05
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8814 - loss: 0.3189
# Epoch 29: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8819 - loss: 0.3182 - val_accuracy: 0.8630 - val_loss: 0.4335 - learning_rate: 1.0000e-06
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8965 - loss: 0.2856
# Epoch 30: val_accuracy did not improve from 0.87671
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8961 - loss: 0.2864 - val_accuracy: 0.8664 - val_loss: 0.4285 - learning_rate: 1.0000e-06

# %%
history_dict = history.history
print(f"History: {history_dict}")
# Out:
# History: {'accuracy': [0.45532646775245667, 0.6606529355049133, 0.7147766351699829, 0.7474226951599121, 0.7929553389549255, 0.800687313079834, 0.8032646179199219, 0.8152921199798584, 0.818728506565094, 0.8402062058448792, 0.8479381203651428, 0.8419243693351746, 0.8539518713951111, 0.8599656224250793, 0.8634020686149597, 0.8565292358398438, 0.8668385148048401, 0.8797250986099243, 0.876288652420044, 0.880584180355072, 0.8771477937698364, 0.8840206265449524, 0.8848797082901001, 0.8994845151901245, 0.8908934593200684, 0.8891752362251282, 0.8857388496398926, 0.8960481286048889, 0.8900343775749207, 0.8883161544799805], 'loss': [1.2316783666610718, 0.9548447728157043, 0.7971740961074829, 0.7116562128067017, 0.6324857473373413, 0.5588782429695129, 0.5382822751998901, 0.5426898002624512, 0.4894082546234131, 0.462790310382843, 0.43678006529808044, 0.439249724149704, 0.4044785499572754, 0.39854320883750916, 0.4011717140674591, 0.4052679240703583, 0.36981451511383057, 0.33825552463531494, 0.3667869567871094, 0.326866090297699, 0.32123881578445435, 0.32594063878059387, 0.3247688412666321, 0.3014988601207733, 0.32218748331069946, 0.2989089787006378, 0.31899285316467285, 0.31541356444358826, 0.30611035227775574, 0.3006584346294403], 'val_accuracy': [0.32534247636795044, 0.32534247636795044, 0.4006849229335785, 0.7773972749710083, 0.7602739930152893, 0.7910959124565125, 0.8287671208381653, 0.8253424763679504, 0.8561643958091736, 0.8561643958091736, 0.8595890402793884, 0.8424657583236694, 0.8424657583236694, 0.8630136847496033, 0.8595890402793884, 0.8527397513389587, 0.8458904027938843, 0.8698630332946777, 0.8767123222351074, 0.8630136847496033, 0.8732876777648926, 0.8630136847496033, 0.8527397513389587, 0.8527397513389587, 0.8664383292198181, 0.8698630332946777, 0.8664383292198181, 0.8630136847496033, 0.8630136847496033, 0.8664383292198181], 'val_loss': [1.3608136177062988, 1.3705565929412842, 1.2271369695663452, 0.6668682098388672, 0.5936287641525269, 0.5657021403312683, 0.5201737880706787, 0.5272619128227234, 0.5014529228210449, 0.46998417377471924, 0.47447219491004944, 0.46201851963996887, 0.47551146149635315, 0.4373604357242584, 0.4282805919647217, 0.41703811287879944, 0.4498506188392639, 0.4168742001056671, 0.42967233061790466, 0.43000030517578125, 0.4296196401119232, 0.4396722912788391, 0.44116899371147156, 0.44012147188186646, 0.4377165734767914, 0.4348786771297455, 0.43555131554603577, 0.42831939458847046, 0.4335053265094757, 0.42849403619766235], 'learning_rate': [9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-05, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999974752427e-07, 9.999999974752427e-07]}

# %%
training_time = end_time_training - start_time_training
hours, remainder = divmod(training_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Training time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Training time: 0 hours, 17 minutes, 40.91 seconds

# %% [markdown]
# ##**Save the model**

# %%
save_epoch_history(history, save_path_history)
# Out:
# History has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1).csv

# %%
save_model(chao_kuay_model, save_path_h5, save_path_keras, save_path_json)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1).keras
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1).h5
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini_Modify_A/appleDataset_42(1)/Adam/MBNv3Small_Mini_Modify_A_appleDataset_Adam_42(1).json

# %% [markdown]
# #**Section 7: Model Evaluation**

# %%
start_time_evaluate = time()
test_acc = chao_kuay_model.evaluate(test_images, verbose=1)
print(f"Final Test Accuracy: {test_acc[1]}, Final Test Loss: {test_acc[0]}")
end_time_evaluate = time()
evaluate_time = end_time_evaluate - start_time_evaluate
hours, remainder = divmod(evaluate_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Evaluation time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8449 - loss: 0.4658
# Final Test Accuracy: 0.8438355922698975, Final Test Loss: 0.4614355266094208
# Evaluation time: 0 hours, 0 minutes, 14.42 seconds

# %%
tr_plot_no_best_epoch(history, 0, paths=img_each_model_dir)

# %%
lr_plot(lr_tracker, history, paths=img_each_model_dir)

# %% [markdown]
# #**Section 8: Making predictions on the Predict Data**

# %%
# พยากรณ์ผลลัพธ์จากโมเดล
predictions = chao_kuay_model.predict(test_images)
# แปลงผลลัพธ์เป็น index ของ class ที่มีค่าความน่าจะเป็นสูงสุด
predicted_indices = np.argmax(predictions, axis=1)
# ดึงข้อมูล mapping ระหว่าง index กับ class name จาก training set
class_index_mapping = train_images.class_indices
# สลับ key กับ value เพื่อแปลงจาก index กลับไปเป็นชื่อ class
index_to_class = dict((v, k) for k, v in class_index_mapping.items())
# แปลง predicted index ให้เป็นชื่อ class ที่เกี่ยวข้อง
predicted_classes = [index_to_class[index] for index in predicted_indices]
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step

# %% [markdown]
# ##**Misclass Predicted**

# %%
incorrect_index = [i for i in range(len(TEST_DF)) if TEST_DF.Label.iloc[i] != predicted_classes[i]]

# สร้าง DataFrame ใหม่ที่มีเฉพาะแถวที่ทำนายผิด
misclassified_df = TEST_DF.iloc[incorrect_index].copy()
# เพิ่มคอลัมน์ Predicted Label ลงใน DataFrame
misclassified_df['Predicted Label'] = [predicted_classes[i] for i in incorrect_index]  # เปลี่ยนชื่อให้ตรงกับที่ต้องการ
# เลือกคอลัมน์ Filepath, Label (True Label), และ Predicted Label
result_misclass_df = misclassified_df[['Filepath', 'Label', 'Predicted Label']]
# เปลี่ยนชื่อคอลัมน์ Label เป็น True Label
result_misclass_df = result_misclass_df.rename(columns={'Label': 'True Label'})

print("Misclassified Dataframe Detail:")
result_misclass_df
# Out:
# Misclassified Dataframe Detail:
#                                               Filepath        True Label  \
# 8         /content/appleDataset/healthy/Train_1285.jpg           healthy
# 11            /content/appleDataset/scab/Train_663.jpg              scab
# 12   /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 42            /content/appleDataset/scab/Train_854.jpg              scab
# 52         /content/appleDataset/healthy/Train_872.jpg           healthy
# 53   /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 55            /content/appleDataset/scab/Train_797.jpg              scab
# 58             /content/appleDataset/scab/Train_76.jpg              scab
# 59        /content/appleDataset/healthy/Train_1691.jpg           healthy
# 63           /content/appleDataset/scab/Train_1520.jpg              scab
# 73           /content/appleDataset/scab/Train_1383.jpg              scab
# 80           /content/appleDataset/scab/Train_1403.jpg              scab
# 83            /content/appleDataset/rust/Train_582.jpg              rust
# 92         /content/appleDataset/healthy/Train_918.jpg           healthy
# 94           /content/appleDataset/scab/Train_1315.jpg              scab
# 100           /content/appleDataset/scab/Train_303.jpg              scab
# 103  /content/appleDataset/multiple_disease/Train_3...  multiple_disease
# 108  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 109  /content/appleDataset/multiple_disease/Train_3...  multiple_disease
# 117  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 121          /content/appleDataset/scab/Train_1727.jpg              scab
# 122       /content/appleDataset/healthy/Train_1223.jpg           healthy
# 127           /content/appleDataset/rust/Train_187.jpg              rust
# 130          /content/appleDataset/rust/Train_1292.jpg              rust
# 156          /content/appleDataset/rust/Train_1439.jpg              rust
# 166           /content/appleDataset/scab/Train_751.jpg              scab
# 172  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 175       /content/appleDataset/healthy/Train_1457.jpg           healthy
# 196           /content/appleDataset/scab/Train_771.jpg              scab
# 212       /content/appleDataset/healthy/Train_1774.jpg           healthy
# 214  /content/appleDataset/multiple_disease/Train_2...  multiple_disease
# 216           /content/appleDataset/scab/Train_994.jpg              scab
# 218  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 236        /content/appleDataset/healthy/Train_425.jpg           healthy
# 241          /content/appleDataset/scab/Train_1572.jpg              scab
# 250           /content/appleDataset/scab/Train_316.jpg              scab
# 254           /content/appleDataset/scab/Train_437.jpg              scab
# 256  /content/appleDataset/multiple_disease/Train_9...  multiple_disease
# 260  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 272        /content/appleDataset/healthy/Train_278.jpg           healthy
# 274  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 279          /content/appleDataset/scab/Train_1120.jpg              scab
# 292          /content/appleDataset/scab/Train_1522.jpg              scab
# 300       /content/appleDataset/healthy/Train_1617.jpg           healthy
# 310          /content/appleDataset/rust/Train_1291.jpg              rust
# 313           /content/appleDataset/rust/Train_799.jpg              rust
# 318       /content/appleDataset/healthy/Train_1563.jpg           healthy
# 320           /content/appleDataset/scab/Train_904.jpg              scab
# 323  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
# 325           /content/appleDataset/rust/Train_472.jpg              rust
# 329          /content/appleDataset/healthy/Train_5.jpg           healthy
# 337          /content/appleDataset/rust/Train_1327.jpg              rust
# 340           /content/appleDataset/rust/Train_426.jpg              rust
# 349        /content/appleDataset/healthy/Train_430.jpg           healthy
# 353          /content/appleDataset/scab/Train_1523.jpg              scab
# 358          /content/appleDataset/scab/Train_1393.jpg              scab
# 363  /content/appleDataset/multiple_disease/Train_1...  multiple_disease
#
#       Predicted Label
# 8                rust
# 11            healthy
# 12            healthy
# 42               rust
# 52   multiple_disease
# 53            healthy
# 55               rust
# 58   multiple_disease
# 59               rust
# 63            healthy
# 73               rust
# 80            healthy
# 83            healthy
# 92               rust
# 94               rust
# 100           healthy
# 103              rust
# 108              rust
# 109              rust
# 117           healthy
# 121           healthy
# 122              rust
# 127           healthy
# 130           healthy
# 156           healthy
# 166           healthy
# 172              scab
# 175              scab
# 196  multiple_disease
# 212              rust
# 214              scab
# 216           healthy
# 218              rust
# 236              rust
# 241           healthy
# 250           healthy
# 254           healthy
# 256           healthy
# 260              scab
# 272              rust
# 274              rust
# 279           healthy
# 292              rust
# 300              rust
# 310  multiple_disease
# 313           healthy
# 318              rust
# 320           healthy
# 323              scab
# 325           healthy
# 329              scab
# 337  multiple_disease
# 340           healthy
# 349              rust
# 353           healthy
# 358              rust
# 363           healthy

# %%
y_test = list(TEST_DF.Label)
report = classification_report(y_test, predicted_classes, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df
# Out:
#                   precision    recall  f1-score     support
# healthy            0.782609  0.873786  0.825688  103.000000
# multiple_disease   0.444444  0.222222  0.296296   18.000000
# rust               0.846715  0.928000  0.885496  125.000000
# scab               0.942308  0.823529  0.878924  119.000000
# accuracy           0.843836  0.843836  0.843836    0.843836
# macro avg          0.754019  0.711885  0.721601  365.000000
# weighted avg       0.839953  0.843836  0.837420  365.000000

# %% [markdown]
# ##**Plot ROC Curve**

# %%
plot_roc_curve(y_test, predictions, paths=img_each_model_dir)

# %% [markdown]
# ##**Plot Confusion Matrix**

# %%
target_names = list(index_to_class.values())
cm = confusion_matrix(y_test, predicted_classes)
plot_confusion_matrix(cm=cm, target_names=target_names, title='Confusion Matrix', fontsize=20, paths=img_each_model_dir)

# %%
plot_confusion_matrix(cm=cm, target_names=target_names, title='Confusion Matrix Normalize', normalize = True, fontsize=20, paths=img_each_model_dir)

# %% [markdown]
# ##**Load Model Test**

# %%
load_model = keras.saving.load_model(save_path_keras)

# %%
start_time_evaluate = time()
test_acc_load = load_model.evaluate(test_images, verbose=1)
print(f"Final Test Accuracy: {test_acc_load[1]}, Final Test Loss: {test_acc_load[0]}")
end_time_evaluate = time()
evaluate_time = end_time_evaluate - start_time_evaluate
hours, remainder = divmod(evaluate_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Evaluation time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 914ms/step - accuracy: 0.8449 - loss: 0.4658
# Final Test Accuracy: 0.8438355922698975, Final Test Loss: 0.4614355266094208
# Evaluation time: 0 hours, 0 minutes, 11.93 seconds
