# %% [markdown]
# #**Benchmark**

# %% [markdown]
# #**Section 1: Import Important Library**

# %%
import warnings
warnings.filterwarnings('ignore')

from datetime import datetime
import pytz
from time import time

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import font_manager
import seaborn as sns
import itertools
import psutil

import cv2
import shutil
import PIL
import os
from pathlib import Path
import sys

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize, LabelEncoder, LabelBinarizer

import random as rd
import numpy as np
import zipfile

# %%
import tensorflow as tf
os.environ["KERAS_BACKEND"] = "tensorflow"
import keras

# %%
from google.colab import drive
drive.mount('/content/drive')

sys.path.append('/content/drive/MyDrive/projectPlant/Colab')
from my_model import *
from helper_functions import *
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Detail of Python Notebook in Google Colab**

# %%
# !nvidia-smi

import subprocess
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {tf.keras.__version__}")
print("-------------------------------------------------------------")
print(f"Python {sys.version}")
print("-------------------------------------------------------------")

# ตรวจสอบ GPU
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("Running on GPU")
    strategy = tf.distribute.MirroredStrategy()
    print(f"Number of GPUs Available: {len(gpus)}")

    # ดึงข้อมูล GPU Memory
    try:
        result = subprocess.run(
            ['nvidia-smi', '--query-gpu=memory.total', '--format=csv,noheader,nounits'],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )
        gpu_memory = result.stdout.strip().split('\n')
        for idx, mem in enumerate(gpu_memory):
            print(f"GPU {idx}: Total Memory: {int(mem) / 1024:.2f} GB")
    except FileNotFoundError:
        print("nvidia-smi is not available on this system.")
else:
    print("No GPU detected. Running on CPU")
    strategy = tf.distribute.get_strategy()

# แสดงจำนวนอุปกรณ์ที่พร้อมใช้งาน
print("Number of replicas:", strategy.num_replicas_in_sync)
print("-------------------------------------------------------------")

# แสดงจำนวน RAM ทั้งหมด
total_ram = psutil.virtual_memory().total / (1024 ** 3)
print(f"Total RAM of Colab instance: {total_ram:.2f} GB")
print("-------------------------------------------------------------")

# แสดงเวลาปัจจุบันในเขตเวลาไทย
thailand_tz = pytz.timezone('Asia/Bangkok')
current_time = datetime.now(thailand_tz).strftime("%Y-%m-%d %H:%M:%S")
print("Current Time (Thailand):", current_time)
# Out:
# Tue Aug 26 03:32:08 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Tensorflow version: 2.19.0
# Keras version: 3.10.0
# -------------------------------------------------------------
# Python 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# -------------------------------------------------------------
# Running on GPU
# Number of GPUs Available: 1
# GPU 0: Total Memory: 15.00 GB
# Number of replicas: 1
# -------------------------------------------------------------
# Total RAM of Colab instance: 12.67 GB
# -------------------------------------------------------------
# Current Time (Thailand): 2025-08-26 10:32:09

# %% [markdown]
# **Initialize Setting (Focus First)**

# %%
SEED=42
np.random.seed(SEED)
tf.random.set_seed(SEED)
rd.seed(SEED)
BATCH_SIZE = 64

# %%
root_dir = '/content/drive/MyDrive/projectPlant/'
title = 'PlantVillage Dataset'
dataset_name = 'plantVillageDataset'
dataset_dir = root_dir + dataset_name

# %%
current_dir = os.getcwd()

# %%
zip_filename = 'plantVillage_dataset_raw.zip'
zip_dir = dataset_dir + '/' + zip_filename

with zipfile.ZipFile(zip_dir, 'r') as zip_ref: # แตกไฟล์จาก G-Drive มาที่ Runtime Directory
    zip_ref.extractall(current_dir)
print(f"Unzip complete at {current_dir}")
# Out:
# Unzip complete at /content

# %%
locations = [f"{root_dir}Extra2/Font"]
font_files = font_manager.findSystemFonts(fontpaths=locations)
print(font_files[0])
for file in font_files:
  font_manager.fontManager.addfont(file)
# Out:
# /content/drive/MyDrive/projectPlant/Extra2/Font/OPTITimes-Roman.otf

# %% [markdown]
# #**Section 2: Load Dataset**

# %%
model_name = 'MBNv3Small'
otmz_name = 'Adam'
seed_num = f"{SEED}"
rounds_num = '1'

# %%
img_dir = root_dir + 'Extra2/' + dataset_name
sample_img_dir = img_dir + '/SampleImages'
img_each_model_dir = img_dir + '/' + model_name + '_' + dataset_name + '_' + otmz_name + '_' + seed_num + '(' + rounds_num + ')'
excel_dir = root_dir + 'DatasetSetting/' + dataset_name + '/' + 'split_data_seed_' + seed_num + '.xlsx'

# %%
os.makedirs(img_dir, exist_ok=True)
os.makedirs(sample_img_dir, exist_ok=True)
os.makedirs(img_each_model_dir, exist_ok=True)

# %% [markdown]
# #**Section 3: Placing data into a Dataframe**

# %% [markdown]
# ##**Convert to dataframe**

# %%
TRAIN_DF, VALID_DF, TEST_DF = to_dataframe_excel(path=excel_dir, sheet_name='Split-Data', mode='single', condition=False, labels_mapping=None)

# %%
print(f"Train Dataframe\n")
print(f"Total images: {len(TRAIN_DF)}")
print(f"Total classes: {TRAIN_DF['Label'].nunique()}")
TRAIN_DF
# Out:
# Train Dataframe
#
# Total images: 13208
# Total classes: 15
#                                                 Filepath  \
# 0      /content/drive/MyDrive/projectPlant/plantVilla...
# 1      /content/drive/MyDrive/projectPlant/plantVilla...
# 2      /content/drive/MyDrive/projectPlant/plantVilla...
# 3      /content/drive/MyDrive/projectPlant/plantVilla...
# 4      /content/drive/MyDrive/projectPlant/plantVilla...
# ...                                                  ...
# 13203  /content/drive/MyDrive/projectPlant/plantVilla...
# 13204  /content/drive/MyDrive/projectPlant/plantVilla...
# 13205  /content/drive/MyDrive/projectPlant/plantVilla...
# 13206  /content/drive/MyDrive/projectPlant/plantVilla...
# 13207  /content/drive/MyDrive/projectPlant/plantVilla...
#
#                                        Label  Original_Index
# 0                      Tomato_Bacterial_spot            5751
# 1                     Pepper__bell___healthy            2155
# 2      Tomato__Tomato_YellowLeaf__Curl_Virus           16158
# 3                      Tomato_Bacterial_spot            5024
# 4                         Tomato_Late_blight            8809
# ...                                      ...             ...
# 13203                       Tomato_Leaf_Mold            9751
# 13204                   Potato___Late_blight            4241
# 13205                    Tomato_Early_blight            7601
# 13206                 Pepper__bell___healthy            2218
# 13207                     Tomato_Late_blight            8915
#
# [13208 rows x 3 columns]

# %%
TRAIN_DF["Filepath"] = TRAIN_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
TRAIN_DF
# Out:
#                                                 Filepath  \
# 0      /content/plantVillageDataset/Tomato_Bacterial_...
# 1      /content/plantVillageDataset/Pepper__bell___he...
# 2      /content/plantVillageDataset/Tomato__Tomato_Ye...
# 3      /content/plantVillageDataset/Tomato_Bacterial_...
# 4      /content/plantVillageDataset/Tomato_Late_bligh...
# ...                                                  ...
# 13203  /content/plantVillageDataset/Tomato_Leaf_Mold/...
# 13204  /content/plantVillageDataset/Potato___Late_bli...
# 13205  /content/plantVillageDataset/Tomato_Early_blig...
# 13206  /content/plantVillageDataset/Pepper__bell___he...
# 13207  /content/plantVillageDataset/Tomato_Late_bligh...
#
#                                        Label  Original_Index
# 0                      Tomato_Bacterial_spot            5751
# 1                     Pepper__bell___healthy            2155
# 2      Tomato__Tomato_YellowLeaf__Curl_Virus           16158
# 3                      Tomato_Bacterial_spot            5024
# 4                         Tomato_Late_blight            8809
# ...                                      ...             ...
# 13203                       Tomato_Leaf_Mold            9751
# 13204                   Potato___Late_blight            4241
# 13205                    Tomato_Early_blight            7601
# 13206                 Pepper__bell___healthy            2218
# 13207                     Tomato_Late_blight            8915
#
# [13208 rows x 3 columns]

# %%
print(f"Validation Dataframe\n")
print(f"Total images: {len(VALID_DF)}")
print(f"Total classes: {VALID_DF['Label'].nunique()}")
VALID_DF
# Out:
# Validation Dataframe
#
# Total images: 3302
# Total classes: 15
#                                                Filepath  \
# 0     /content/drive/MyDrive/projectPlant/plantVilla...
# 1     /content/drive/MyDrive/projectPlant/plantVilla...
# 2     /content/drive/MyDrive/projectPlant/plantVilla...
# 3     /content/drive/MyDrive/projectPlant/plantVilla...
# 4     /content/drive/MyDrive/projectPlant/plantVilla...
# ...                                                 ...
# 3297  /content/drive/MyDrive/projectPlant/plantVilla...
# 3298  /content/drive/MyDrive/projectPlant/plantVilla...
# 3299  /content/drive/MyDrive/projectPlant/plantVilla...
# 3300  /content/drive/MyDrive/projectPlant/plantVilla...
# 3301  /content/drive/MyDrive/projectPlant/plantVilla...
#
#                                             Label  Original_Index
# 0           Tomato__Tomato_YellowLeaf__Curl_Virus           15877
# 1     Tomato_Spider_mites_Two_spotted_spider_mite           13525
# 2                                  Tomato_healthy           19272
# 3           Tomato__Tomato_YellowLeaf__Curl_Virus           16427
# 4                             Tomato__Target_Spot           14005
# ...                                           ...             ...
# 3297                          Tomato__Target_Spot           14105
# 3298                        Tomato_Bacterial_spot            6432
# 3299                Pepper__bell___Bacterial_spot              60
# 3300                             Potato___healthy            4523
# 3301                          Tomato_Early_blight            7347
#
# [3302 rows x 3 columns]

# %%
VALID_DF["Filepath"] = VALID_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
VALID_DF
# Out:
#                                                Filepath  \
# 0     /content/plantVillageDataset/Tomato__Tomato_Ye...
# 1     /content/plantVillageDataset/Tomato_Spider_mit...
# 2     /content/plantVillageDataset/Tomato_healthy/98...
# 3     /content/plantVillageDataset/Tomato__Tomato_Ye...
# 4     /content/plantVillageDataset/Tomato__Target_Sp...
# ...                                                 ...
# 3297  /content/plantVillageDataset/Tomato__Target_Sp...
# 3298  /content/plantVillageDataset/Tomato_Bacterial_...
# 3299  /content/plantVillageDataset/Pepper__bell___Ba...
# 3300  /content/plantVillageDataset/Potato___healthy/...
# 3301  /content/plantVillageDataset/Tomato_Early_blig...
#
#                                             Label  Original_Index
# 0           Tomato__Tomato_YellowLeaf__Curl_Virus           15877
# 1     Tomato_Spider_mites_Two_spotted_spider_mite           13525
# 2                                  Tomato_healthy           19272
# 3           Tomato__Tomato_YellowLeaf__Curl_Virus           16427
# 4                             Tomato__Target_Spot           14005
# ...                                           ...             ...
# 3297                          Tomato__Target_Spot           14105
# 3298                        Tomato_Bacterial_spot            6432
# 3299                Pepper__bell___Bacterial_spot              60
# 3300                             Potato___healthy            4523
# 3301                          Tomato_Early_blight            7347
#
# [3302 rows x 3 columns]

# %%
print(f"Test Dataframe\n")
print(f"Total images: {len(TEST_DF)}")
print(f"Total classes: {TEST_DF['Label'].nunique()}")
TEST_DF
# Out:
# Test Dataframe
#
# Total images: 4128
# Total classes: 15
#                                                Filepath  \
# 0     /content/drive/MyDrive/projectPlant/plantVilla...
# 1     /content/drive/MyDrive/projectPlant/plantVilla...
# 2     /content/drive/MyDrive/projectPlant/plantVilla...
# 3     /content/drive/MyDrive/projectPlant/plantVilla...
# 4     /content/drive/MyDrive/projectPlant/plantVilla...
# ...                                                 ...
# 4123  /content/drive/MyDrive/projectPlant/plantVilla...
# 4124  /content/drive/MyDrive/projectPlant/plantVilla...
# 4125  /content/drive/MyDrive/projectPlant/plantVilla...
# 4126  /content/drive/MyDrive/projectPlant/plantVilla...
# 4127  /content/drive/MyDrive/projectPlant/plantVilla...
#
#                                             Label  Original_Index
# 0                           Potato___Early_blight            2655
# 1     Tomato_Spider_mites_Two_spotted_spider_mite           12257
# 2                              Tomato_Late_blight            8851
# 3     Tomato_Spider_mites_Two_spotted_spider_mite           12831
# 4                              Tomato_Late_blight            9140
# ...                                           ...             ...
# 4123                               Tomato_healthy           19299
# 4124                             Tomato_Leaf_Mold            9885
# 4125                           Tomato_Late_blight            7976
# 4126                        Tomato_Bacterial_spot            5742
# 4127                           Tomato_Late_blight            9024
#
# [4128 rows x 3 columns]

# %%
TEST_DF["Filepath"] = TEST_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
TEST_DF
# Out:
#                                                Filepath  \
# 0     /content/plantVillageDataset/Potato___Early_bl...
# 1     /content/plantVillageDataset/Tomato_Spider_mit...
# 2     /content/plantVillageDataset/Tomato_Late_bligh...
# 3     /content/plantVillageDataset/Tomato_Spider_mit...
# 4     /content/plantVillageDataset/Tomato_Late_bligh...
# ...                                                 ...
# 4123  /content/plantVillageDataset/Tomato_healthy/9d...
# 4124  /content/plantVillageDataset/Tomato_Leaf_Mold/...
# 4125  /content/plantVillageDataset/Tomato_Late_bligh...
# 4126  /content/plantVillageDataset/Tomato_Bacterial_...
# 4127  /content/plantVillageDataset/Tomato_Late_bligh...
#
#                                             Label  Original_Index
# 0                           Potato___Early_blight            2655
# 1     Tomato_Spider_mites_Two_spotted_spider_mite           12257
# 2                              Tomato_Late_blight            8851
# 3     Tomato_Spider_mites_Two_spotted_spider_mite           12831
# 4                              Tomato_Late_blight            9140
# ...                                           ...             ...
# 4123                               Tomato_healthy           19299
# 4124                             Tomato_Leaf_Mold            9885
# 4125                           Tomato_Late_blight            7976
# 4126                        Tomato_Bacterial_spot            5742
# 4127                           Tomato_Late_blight            9024
#
# [4128 rows x 3 columns]

# %% [markdown]
# #**Section 4: Data Preparing**

# %%
IMAGE_SIZE = (224, 224)
IMAGE_SHAPE = (224, 224, 3)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=keras.applications.mobilenet_v3.preprocess_input,
    horizontal_flip=True,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    brightness_range=[0.9, 1.1],
    fill_mode='nearest'
)

valid_test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=keras.applications.mobilenet_v3.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe = TRAIN_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed = SEED
)

val_images = valid_test_generator.flow_from_dataframe(
    dataframe = VALID_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed = SEED
)

test_images = valid_test_generator.flow_from_dataframe(
    dataframe = TEST_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = False
)
# Out:
# Found 13208 validated image filenames belonging to 15 classes.
# Found 3302 validated image filenames belonging to 15 classes.
# Found 4128 validated image filenames belonging to 15 classes.

# %% [markdown]
# #**Section 5: Preparing the Model**

# %%
checkpoint_path, save_path_h5, save_path_keras, save_path_json, save_path_history, save_path_tensorboard = save_path(otmz_name=otmz_name, dataset_name=dataset_name, rounds=rounds_num, model=model_name, seed=SEED)
print("Recheck save path: \n")
print(f"Checkpoint path: {checkpoint_path}")
print(f"Save path h5: {save_path_h5}")
print(f"Save path keras: {save_path_keras}")
print(f"Save path json: {save_path_json}")
print(f"Save path history: {save_path_history}")
print(f"Save path tensorboard: {save_path_tensorboard}")
# Out:
# Recheck save path:
#
# Checkpoint path: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# Save path h5: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1).h5
# Save path keras: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1).keras
# Save path json: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1).json
# Save path history: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1).csv
# Save path tensorboard: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_tensorboard_logs

# %% [markdown]
# ##**Create Model Callback**

# %%
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_path,
    monitor = 'val_accuracy',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False,
    mode = 'auto'
)

class LearningRateTracker(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        # Access learning rate through learning_rate property
        lr = self.model.optimizer.learning_rate.numpy()  # This will now work correctly
        logs = logs or {}
        logs['lr'] = lr

        if not hasattr(self, 'learning_rates'):
            self.learning_rates = []
        self.learning_rates.append(lr)

# Create the callback instance
lr_tracker = LearningRateTracker()

tensorlog = keras.callbacks.TensorBoard(
    log_dir = save_path_tensorboard,
    histogram_freq = 1,
    write_graph = True,
    write_images = True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor = 'val_loss',
    factor = 0.1,
    patience = 5,
    verbose = 1,
    min_lr = 1e-06
)

# %% [markdown]
# ##**Model Parameters**

# %%
chao_kuay_model = build_model(model_name="MobileNetV3Small", input_shape=IMAGE_SHAPE, num_classes=len(train_images.class_indices))
chao_kuay_model.compile(
    optimizer = keras.optimizers.Adam(
        learning_rate = 1e-03,
        beta_1 = 0.9,
        beta_2 = 0.999,
        epsilon = 1e-07,
        name = 'Adam'
    ),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
chao_kuay_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 113, 113,  │          0 │ activation[0][0]  │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 56, 56,    │        144 │ expanded_conv_de… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 56, 56,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 56, 56,    │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 16)  │          0 │ re_lu[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 8)   │        136 │ expanded_conv_sq… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 8)   │          0 │ expanded_conv_sq… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 16)  │        144 │ expanded_conv_sq… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 16)  │          0 │ expanded_conv_sq… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 1, 1, 16)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 1, 16)  │          0 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 56, 56,    │          0 │ re_lu[0][0],      │
# │ (Multiply)          │ 16)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 56, 56,    │        256 │ expanded_conv_sq… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 56, 56,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 56, 56,    │      1,152 │ expanded_conv_pr… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 56, 56,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 57, 57,    │          0 │ re_lu_2[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 28, 28,    │        648 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 28, 28,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 28, 28,    │      1,728 │ re_lu_3[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 28, 28,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 28, 28,    │      2,112 │ expanded_conv_1_… │
# │ (Conv2D)            │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 28, 28,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 28, 28,    │        792 │ re_lu_4[0][0]     │
# │ (DepthwiseConv2D)   │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 28, 28,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 28, 28,    │      2,112 │ re_lu_5[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 28, 28,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 28, 28,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 28, 28,    │      2,304 │ expanded_conv_2_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 28, 28,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 31, 31,    │          0 │ activation_1[0][… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 14, 14,    │      2,400 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 14, 14,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 14, 14,    │          0 │ expanded_conv_3_… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 96)  │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      2,328 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 96)  │      2,400 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 96)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 1, 1, 96)  │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 1, 96)  │          0 │ re_lu_6[0][0]     │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 14, 14,    │          0 │ activation_2[0][… │
# │ (Multiply)          │ 96)               │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 14, 14,    │      3,840 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 14, 14,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 14, 14,    │      9,600 │ expanded_conv_3_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 14, 14,    │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 14, 14,    │      6,000 │ activation_3[0][… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 14, 14,    │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 240) │          0 │ activation_4[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 64)  │     15,424 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 64)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 240) │     15,600 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 240) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 1, 1, 240) │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 1, 1, 240) │          0 │ re_lu_7[0][0]     │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 14, 14,    │          0 │ activation_4[0][… │
# │ (Multiply)          │ 240)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 14, 14,    │      9,600 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 14, 14,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 14, 14,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 14, 14,    │      9,600 │ expanded_conv_4_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 14, 14,    │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 14, 14,    │          0 │ expanded_conv_5_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 14, 14,    │      6,000 │ activation_5[0][… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 14, 14,    │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 14, 14,    │          0 │ expanded_conv_5_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 240) │          0 │ activation_6[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 64)  │     15,424 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 64)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 240) │     15,600 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1, 1, 240) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 1, 1, 240) │          0 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 1, 1, 240) │          0 │ re_lu_8[0][0]     │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 14, 14,    │          0 │ activation_6[0][… │
# │ (Multiply)          │ 240)              │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 14, 14,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 14, 14,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 14, 14,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 14, 14,    │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      3,000 │ activation_7[0][… │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 1, 1, 120) │          0 │ activation_8[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_6_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_6_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_6_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_6_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 1, 1, 120) │          0 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 1, 1, 120) │          0 │ re_lu_9[0][0]     │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 14, 14,    │          0 │ activation_8[0][… │
# │ (Multiply)          │ 120)              │            │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │      5,760 │ expanded_conv_6_… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        192 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │      6,912 │ expanded_conv_6_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      3,600 │ activation_9[0][… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 1, 1, 144) │          0 │ activation_10[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 1, 1, 40)  │      5,800 │ expanded_conv_7_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 1, 1, 40)  │          0 │ expanded_conv_7_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 1, 1, 144) │      5,904 │ expanded_conv_7_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 1, 1, 144) │          0 │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 1, 1, 144) │          0 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 1, 1, 144) │          0 │ re_lu_10[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 14, 14,    │          0 │ activation_10[0]… │
# │ (Multiply)          │ 144)              │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │      6,912 │ expanded_conv_7_… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        192 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 48)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     13,824 │ expanded_conv_7_… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 17, 17,    │          0 │ activation_11[0]… │
# │ (ZeroPadding2D)     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │      7,200 │ expanded_conv_8_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 7, 7, 288) │          0 │ expanded_conv_8_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 1, 1, 288) │          0 │ activation_12[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 1, 1, 72)  │     20,808 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 1, 1, 72)  │          0 │ expanded_conv_8_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 1, 1, 288) │     21,024 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 1, 1, 288) │          0 │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 1, 1, 288) │          0 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 1, 1, 288) │          0 │ re_lu_11[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 7, 7, 288) │          0 │ activation_12[0]… │
# │ (Multiply)          │                   │            │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 7, 7, 96)  │     27,648 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 7, 7, 96)  │        384 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 7, 7, 576) │     55,296 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 7, 7, 576) │          0 │ expanded_conv_9_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 7, 7, 576) │     14,400 │ activation_13[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 576) │          0 │ expanded_conv_9_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 1, 1, 576) │          0 │ activation_14[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 1, 1, 144) │     83,088 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 1, 1, 144) │          0 │ expanded_conv_9_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 1, 1, 576) │     83,520 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 1, 1, 576) │          0 │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 1, 1, 576) │          0 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 1, 1, 576) │          0 │ re_lu_12[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 7, 7, 576) │          0 │ activation_14[0]… │
# │ (Multiply)          │                   │            │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 7, 7, 96)  │     55,296 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 7, 7, 96)  │        384 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 7, 7, 96)  │          0 │ expanded_conv_8_… │
# │ (Add)               │                   │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 7, 7, 576) │     55,296 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 576) │          0 │ expanded_conv_10… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 7, 7, 576) │     14,400 │ activation_15[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 7, 7, 576) │          0 │ expanded_conv_10… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 576) │          0 │ activation_16[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 144) │     83,088 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 144) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 576) │     83,520 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 1, 1, 576) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 1, 1, 576) │          0 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 1, 1, 576) │          0 │ re_lu_13[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 7, 7, 576) │          0 │ activation_16[0]… │
# │ (Multiply)          │                   │            │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 7, 7, 96)  │     55,296 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 7, 7, 96)  │        384 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_a… │ (None, 7, 7, 96)  │          0 │ expanded_conv_9_… │
# │ (Add)               │                   │            │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 576) │     55,296 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 576) │      2,304 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 7, 7, 576) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 576)       │          0 │ activation_17[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Predictions (Dense) │ (None, 15)        │      8,655 │ avg_pool[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 947,775 (3.62 MB)
#  Trainable params: 8,655 (33.81 KB)
#  Non-trainable params: 939,120 (3.58 MB)

# %% [markdown]
# #**Section 6: Training the model**

# %%
start_time_training = time()

history = chao_kuay_model.fit(
    x = train_images,
    validation_data = val_images,
    batch_size = BATCH_SIZE,
    callbacks = [model_checkpoint, tensorlog, lr_tracker, reduce_lr],
    epochs = 30,
)

end_time_training = time()
# Out:
# Epoch 1/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4228 - loss: 1.9601
# Epoch 1: val_accuracy improved from -inf to 0.76408, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 250s 1s/step - accuracy: 0.4238 - loss: 1.9574 - val_accuracy: 0.7641 - val_loss: 0.8082 - learning_rate: 0.0010
# Epoch 2/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 974ms/step - accuracy: 0.8114 - loss: 0.7326
# Epoch 2: val_accuracy improved from 0.76408 to 0.84827, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 229s 1s/step - accuracy: 0.8114 - loss: 0.7323 - val_accuracy: 0.8483 - val_loss: 0.5424 - learning_rate: 0.0010
# Epoch 3/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 974ms/step - accuracy: 0.8614 - loss: 0.5277
# Epoch 3: val_accuracy improved from 0.84827 to 0.86644, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.8614 - loss: 0.5276 - val_accuracy: 0.8664 - val_loss: 0.4525 - learning_rate: 0.0010
# Epoch 4/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 961ms/step - accuracy: 0.8863 - loss: 0.4350
# Epoch 4: val_accuracy improved from 0.86644 to 0.89128, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 0.8863 - loss: 0.4349 - val_accuracy: 0.8913 - val_loss: 0.3857 - learning_rate: 0.0010
# Epoch 5/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 961ms/step - accuracy: 0.8982 - loss: 0.3791
# Epoch 5: val_accuracy improved from 0.89128 to 0.89158, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 0.8982 - loss: 0.3790 - val_accuracy: 0.8916 - val_loss: 0.3687 - learning_rate: 0.0010
# Epoch 6/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 980ms/step - accuracy: 0.9098 - loss: 0.3432
# Epoch 6: val_accuracy improved from 0.89158 to 0.89824, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.9098 - loss: 0.3432 - val_accuracy: 0.8982 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 7/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - accuracy: 0.9162 - loss: 0.3078
# Epoch 7: val_accuracy did not improve from 0.89824
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.9162 - loss: 0.3078 - val_accuracy: 0.8964 - val_loss: 0.3407 - learning_rate: 0.0010
# Epoch 8/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.9183 - loss: 0.2954
# Epoch 8: val_accuracy improved from 0.89824 to 0.91127, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.9183 - loss: 0.2954 - val_accuracy: 0.9113 - val_loss: 0.2991 - learning_rate: 0.0010
# Epoch 9/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - accuracy: 0.9154 - loss: 0.2814
# Epoch 9: val_accuracy improved from 0.91127 to 0.91157, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.9154 - loss: 0.2814 - val_accuracy: 0.9116 - val_loss: 0.2912 - learning_rate: 0.0010
# Epoch 10/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 973ms/step - accuracy: 0.9173 - loss: 0.2720
# Epoch 10: val_accuracy improved from 0.91157 to 0.92126, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9173 - loss: 0.2719 - val_accuracy: 0.9213 - val_loss: 0.2746 - learning_rate: 0.0010
# Epoch 11/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.9298 - loss: 0.2468
# Epoch 11: val_accuracy did not improve from 0.92126
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9298 - loss: 0.2468 - val_accuracy: 0.9143 - val_loss: 0.2778 - learning_rate: 0.0010
# Epoch 12/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.9291 - loss: 0.2440
# Epoch 12: val_accuracy did not improve from 0.92126
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9291 - loss: 0.2440 - val_accuracy: 0.9176 - val_loss: 0.2718 - learning_rate: 0.0010
# Epoch 13/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 978ms/step - accuracy: 0.9388 - loss: 0.2197
# Epoch 13: val_accuracy did not improve from 0.92126
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.9388 - loss: 0.2197 - val_accuracy: 0.9197 - val_loss: 0.2640 - learning_rate: 0.0010
# Epoch 14/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 981ms/step - accuracy: 0.9376 - loss: 0.2076
# Epoch 14: val_accuracy improved from 0.92126 to 0.92247, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.9376 - loss: 0.2076 - val_accuracy: 0.9225 - val_loss: 0.2540 - learning_rate: 0.0010
# Epoch 15/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 983ms/step - accuracy: 0.9382 - loss: 0.2133
# Epoch 15: val_accuracy did not improve from 0.92247
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.9382 - loss: 0.2133 - val_accuracy: 0.9113 - val_loss: 0.2770 - learning_rate: 0.0010
# Epoch 16/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9373 - loss: 0.2098
# Epoch 16: val_accuracy improved from 0.92247 to 0.92611, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.9373 - loss: 0.2098 - val_accuracy: 0.9261 - val_loss: 0.2450 - learning_rate: 0.0010
# Epoch 17/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 965ms/step - accuracy: 0.9391 - loss: 0.2015
# Epoch 17: val_accuracy did not improve from 0.92611
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 0.9391 - loss: 0.2015 - val_accuracy: 0.9170 - val_loss: 0.2593 - learning_rate: 0.0010
# Epoch 18/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - accuracy: 0.9472 - loss: 0.1827
# Epoch 18: val_accuracy improved from 0.92611 to 0.92913, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.9472 - loss: 0.1828 - val_accuracy: 0.9291 - val_loss: 0.2396 - learning_rate: 0.0010
# Epoch 19/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 969ms/step - accuracy: 0.9459 - loss: 0.1832
# Epoch 19: val_accuracy did not improve from 0.92913
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9459 - loss: 0.1832 - val_accuracy: 0.9197 - val_loss: 0.2488 - learning_rate: 0.0010
# Epoch 20/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.9471 - loss: 0.1864
# Epoch 20: val_accuracy did not improve from 0.92913
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9471 - loss: 0.1864 - val_accuracy: 0.9152 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 21/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.9491 - loss: 0.1773
# Epoch 21: val_accuracy did not improve from 0.92913
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 0.9490 - loss: 0.1774 - val_accuracy: 0.9273 - val_loss: 0.2377 - learning_rate: 0.0010
# Epoch 22/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.9517 - loss: 0.1666
# Epoch 22: val_accuracy did not improve from 0.92913
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 0.9517 - loss: 0.1666 - val_accuracy: 0.9234 - val_loss: 0.2451 - learning_rate: 0.0010
# Epoch 23/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 970ms/step - accuracy: 0.9489 - loss: 0.1752
# Epoch 23: val_accuracy did not improve from 0.92913
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 211s 1s/step - accuracy: 0.9489 - loss: 0.1752 - val_accuracy: 0.9273 - val_loss: 0.2293 - learning_rate: 0.0010
# Epoch 24/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 970ms/step - accuracy: 0.9491 - loss: 0.1701
# Epoch 24: val_accuracy improved from 0.92913 to 0.93156, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 211s 1s/step - accuracy: 0.9491 - loss: 0.1701 - val_accuracy: 0.9316 - val_loss: 0.2274 - learning_rate: 0.0010
# Epoch 25/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 964ms/step - accuracy: 0.9480 - loss: 0.1669
# Epoch 25: val_accuracy improved from 0.93156 to 0.93337, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 0.9480 - loss: 0.1669 - val_accuracy: 0.9334 - val_loss: 0.2137 - learning_rate: 0.0010
# Epoch 26/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 975ms/step - accuracy: 0.9502 - loss: 0.1645
# Epoch 26: val_accuracy did not improve from 0.93337
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 0.9502 - loss: 0.1645 - val_accuracy: 0.9228 - val_loss: 0.2333 - learning_rate: 0.0010
# Epoch 27/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 964ms/step - accuracy: 0.9537 - loss: 0.1597
# Epoch 27: val_accuracy improved from 0.93337 to 0.93580, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9537 - loss: 0.1597 - val_accuracy: 0.9358 - val_loss: 0.2067 - learning_rate: 0.0010
# Epoch 28/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.9546 - loss: 0.1586
# Epoch 28: val_accuracy did not improve from 0.93580
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 0.9545 - loss: 0.1586 - val_accuracy: 0.9346 - val_loss: 0.2129 - learning_rate: 0.0010
# Epoch 29/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 965ms/step - accuracy: 0.9523 - loss: 0.1585
# Epoch 29: val_accuracy did not improve from 0.93580
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.9523 - loss: 0.1585 - val_accuracy: 0.9319 - val_loss: 0.2164 - learning_rate: 0.0010
# Epoch 30/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.9539 - loss: 0.1591
# Epoch 30: val_accuracy did not improve from 0.93580
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9539 - loss: 0.1591 - val_accuracy: 0.9297 - val_loss: 0.2240 - learning_rate: 0.0010

# %%
history_dict = history.history
print(f"History: {history_dict}")
# Out:
# History: {'accuracy': [0.6216686964035034, 0.8273016214370728, 0.8654603362083435, 0.8893095254898071, 0.8998334407806396, 0.9074046015739441, 0.9161871671676636, 0.9200484752655029, 0.9201998710632324, 0.9219412207603455, 0.9276953339576721, 0.9304209351539612, 0.9369321465492249, 0.9375378489494324, 0.9395820498466492, 0.9394306540489197, 0.9404149055480957, 0.9448819160461426, 0.9436705112457275, 0.9460175633430481, 0.9463204145431519, 0.9480617642402649, 0.9466232657432556, 0.9508631229400635, 0.9497274160385132, 0.9504088163375854, 0.9543458223342896, 0.9527559280395508, 0.9526801705360413, 0.9547244310379028], 'loss': [1.3913884162902832, 0.6650433540344238, 0.5053347945213318, 0.4217267632484436, 0.37282735109329224, 0.33895331621170044, 0.30780544877052307, 0.2895902693271637, 0.2756315767765045, 0.26347580552101135, 0.2489784061908722, 0.23930032551288605, 0.22238267958164215, 0.21674013137817383, 0.2093837708234787, 0.21050678193569183, 0.2026771605014801, 0.1885075569152832, 0.19038304686546326, 0.18412762880325317, 0.18101681768894196, 0.17695999145507812, 0.17528730630874634, 0.16798703372478485, 0.16624872386455536, 0.16452758014202118, 0.1581190824508667, 0.15817011892795563, 0.1575489044189453, 0.15494705736637115], 'val_accuracy': [0.7640823721885681, 0.848273754119873, 0.8664445877075195, 0.8912780284881592, 0.8915808796882629, 0.8982434868812561, 0.8964263796806335, 0.9112659096717834, 0.9115687608718872, 0.9212598204612732, 0.9142943620681763, 0.9176256656646729, 0.9197456240653992, 0.9224712252616882, 0.9112659096717834, 0.9261053800582886, 0.9170199632644653, 0.9291338324546814, 0.9197456240653992, 0.9152029156684875, 0.9273167848587036, 0.9233797788619995, 0.9273167848587036, 0.9315566420555115, 0.9333736896514893, 0.922774076461792, 0.9357964992523193, 0.9345850944519043, 0.9318594932556152, 0.9297395348548889], 'val_loss': [0.8081850409507751, 0.542438268661499, 0.4525226652622223, 0.38567811250686646, 0.36870551109313965, 0.34343528747558594, 0.3407488167285919, 0.2991131544113159, 0.29120108485221863, 0.2745967507362366, 0.2778240740299225, 0.2717873156070709, 0.2640194892883301, 0.25403475761413574, 0.2770487666130066, 0.24497972428798676, 0.25931501388549805, 0.23957473039627075, 0.248838409781456, 0.2638677656650543, 0.2377152293920517, 0.2451171725988388, 0.22934120893478394, 0.22738276422023773, 0.2136719673871994, 0.23328405618667603, 0.20665407180786133, 0.212860569357872, 0.21638630330562592, 0.2239978164434433], 'learning_rate': [0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513]}

# %%
training_time = end_time_training - start_time_training
hours, remainder = divmod(training_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Training time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Training time: 1 hours, 50 minutes, 44.68 seconds

# %% [markdown]
# ##**Save the model**

# %%
save_epoch_history(history, save_path_history)
# Out:
# History has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1).csv

# %%
save_model(chao_kuay_model, save_path_h5, save_path_keras, save_path_json)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1).keras
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1).h5
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small/plantVillageDataset_42(1)/Adam/MBNv3Small_plantVillageDataset_Adam_42(1).json

# %% [markdown]
# #**Section 7: Model Evaluation**

# %%
start_time_evaluate = time()
test_acc = chao_kuay_model.evaluate(test_images, verbose=1)
print(f"Final Test Accuracy: {test_acc[1]}, Final Test Loss: {test_acc[0]}")
end_time_evaluate = time()
evaluate_time = end_time_evaluate - start_time_evaluate
hours, remainder = divmod(evaluate_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Evaluation time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 16s 247ms/step - accuracy: 0.9240 - loss: 0.2274
# Final Test Accuracy: 0.9328972697257996, Final Test Loss: 0.20297326147556305
# Evaluation time: 0 hours, 0 minutes, 16.28 seconds

# %%
tr_plot_no_best_epoch(history, 0, paths=img_each_model_dir)

# %%
lr_plot(lr_tracker, history, paths=img_each_model_dir)

# %% [markdown]
# #**Section 8: Making predictions on the Predict Data**

# %%
# พยากรณ์ผลลัพธ์จากโมเดล
predictions = chao_kuay_model.predict(test_images)
# แปลงผลลัพธ์เป็น index ของ class ที่มีค่าความน่าจะเป็นสูงสุด
predicted_indices = np.argmax(predictions, axis=1)
# ดึงข้อมูล mapping ระหว่าง index กับ class name จาก training set
class_index_mapping = train_images.class_indices
# สลับ key กับ value เพื่อแปลงจาก index กลับไปเป็นชื่อ class
index_to_class = dict((v, k) for k, v in class_index_mapping.items())
# แปลง predicted index ให้เป็นชื่อ class ที่เกี่ยวข้อง
predicted_classes = [index_to_class[index] for index in predicted_indices]
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 18s 202ms/step

# %% [markdown]
# ##**Misclass Predicted**

# %%
incorrect_index = [i for i in range(len(TEST_DF)) if TEST_DF.Label.iloc[i] != predicted_classes[i]]

# สร้าง DataFrame ใหม่ที่มีเฉพาะแถวที่ทำนายผิด
misclassified_df = TEST_DF.iloc[incorrect_index].copy()
# เพิ่มคอลัมน์ Predicted Label ลงใน DataFrame
misclassified_df['Predicted Label'] = [predicted_classes[i] for i in incorrect_index]  # เปลี่ยนชื่อให้ตรงกับที่ต้องการ
# เลือกคอลัมน์ Filepath, Label (True Label), และ Predicted Label
result_misclass_df = misclassified_df[['Filepath', 'Label', 'Predicted Label']]
# เปลี่ยนชื่อคอลัมน์ Label เป็น True Label
result_misclass_df = result_misclass_df.rename(columns={'Label': 'True Label'})

print("Misclassified Dataframe Detail:")
result_misclass_df
# Out:
# Misclassified Dataframe Detail:
#                                                Filepath  \
# 51    /content/plantVillageDataset/Tomato__Tomato_Ye...
# 54    /content/plantVillageDataset/Potato___Early_bl...
# 56    /content/plantVillageDataset/Tomato__Tomato_Ye...
# 61    /content/plantVillageDataset/Tomato__Tomato_Ye...
# 71    /content/plantVillageDataset/Tomato__Target_Sp...
# ...                                                 ...
# 4018  /content/plantVillageDataset/Tomato__Target_Sp...
# 4046  /content/plantVillageDataset/Tomato_Early_blig...
# 4072  /content/plantVillageDataset/Tomato_Bacterial_...
# 4105  /content/plantVillageDataset/Tomato_Bacterial_...
# 4113  /content/plantVillageDataset/Tomato__Target_Sp...
#
#                                  True Label  \
# 51    Tomato__Tomato_YellowLeaf__Curl_Virus
# 54                    Potato___Early_blight
# 56    Tomato__Tomato_YellowLeaf__Curl_Virus
# 61    Tomato__Tomato_YellowLeaf__Curl_Virus
# 71                      Tomato__Target_Spot
# ...                                     ...
# 4018                    Tomato__Target_Spot
# 4046                    Tomato_Early_blight
# 4072                  Tomato_Bacterial_spot
# 4105                  Tomato_Bacterial_spot
# 4113                    Tomato__Target_Spot
#
#                                   Predicted Label
# 51                      Tomato_Septoria_leaf_spot
# 54                                 Tomato_healthy
# 56                      Tomato_Septoria_leaf_spot
# 61    Tomato_Spider_mites_Two_spotted_spider_mite
# 71                           Potato___Late_blight
# ...                                           ...
# 4018                               Tomato_healthy
# 4046                           Tomato_Late_blight
# 4072                          Tomato_Early_blight
# 4105                    Tomato_Septoria_leaf_spot
# 4113                               Tomato_healthy
#
# [277 rows x 3 columns]

# %%
y_test = list(TEST_DF.Label)
report = classification_report(y_test, predicted_classes, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df
# Out:
#                                              precision    recall  f1-score  \
# Pepper__bell___Bacterial_spot                 0.994924  0.984925  0.989899
# Pepper__bell___healthy                        0.980066  0.996622  0.988275
# Potato___Early_blight                         0.989848  0.975000  0.982368
# Potato___Late_blight                          0.963351  0.920000  0.941176
# Potato___healthy                              0.878788  0.966667  0.920635
# Tomato_Bacterial_spot                         0.960094  0.960094  0.960094
# Tomato_Early_blight                           0.953333  0.715000  0.817143
# Tomato_Late_blight                            0.899263  0.958115  0.927757
# Tomato_Leaf_Mold                              0.932292  0.942105  0.937173
# Tomato_Septoria_leaf_spot                     0.905028  0.915254  0.910112
# Tomato_Spider_mites_Two_spotted_spider_mite   0.852055  0.928358  0.888571
# Tomato__Target_Spot                           0.867704  0.793594  0.828996
# Tomato__Tomato_YellowLeaf__Curl_Virus         0.998361  0.948598  0.972843
# Tomato__Tomato_mosaic_virus                   0.933333  0.933333  0.933333
# Tomato_healthy                                0.861789  1.000000  0.925764
# accuracy                                      0.932897  0.932897  0.932897
# macro avg                                     0.931349  0.929178  0.928276
# weighted avg                                  0.935090  0.932897  0.932291
#
#                                                  support
# Pepper__bell___Bacterial_spot                 199.000000
# Pepper__bell___healthy                        296.000000
# Potato___Early_blight                         200.000000
# Potato___Late_blight                          200.000000
# Potato___healthy                               30.000000
# Tomato_Bacterial_spot                         426.000000
# Tomato_Early_blight                           200.000000
# Tomato_Late_blight                            382.000000
# Tomato_Leaf_Mold                              190.000000
# Tomato_Septoria_leaf_spot                     354.000000
# Tomato_Spider_mites_Two_spotted_spider_mite   335.000000
# Tomato__Target_Spot                           281.000000
# Tomato__Tomato_YellowLeaf__Curl_Virus         642.000000
# Tomato__Tomato_mosaic_virus                    75.000000
# Tomato_healthy                                318.000000
# accuracy                                        0.932897
# macro avg                                    4128.000000
# weighted avg                                 4128.000000

# %% [markdown]
# ##**Plot ROC Curve**

# %%
plot_roc_curve(y_test, predictions, paths=img_each_model_dir)

# %% [markdown]
# ##**Plot Confusion Matrix**

# %%
target_names = list(index_to_class.values())
cm = confusion_matrix(y_test, predicted_classes)
plot_confusion_matrix(cm=cm, target_names=target_names, title='Confusion Matrix', fontsize=16, paths=img_each_model_dir)

# %%
plot_confusion_matrix(cm=cm, target_names=target_names, title='Confusion Matrix Normalize', normalize = True, fontsize=16, paths=img_each_model_dir)

# %% [markdown]
# ##**Load Model Test**

# %%
load_model = keras.saving.load_model(save_path_keras)

# %%
start_time_evaluate = time()
test_acc_load = load_model.evaluate(test_images, verbose=1)
print(f"Final Test Accuracy: {test_acc_load[1]}, Final Test Loss: {test_acc_load[0]}")
end_time_evaluate = time()
evaluate_time = end_time_evaluate - start_time_evaluate
hours, remainder = divmod(evaluate_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Evaluation time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 17s 185ms/step - accuracy: 0.9240 - loss: 0.2274
# Final Test Accuracy: 0.9328972697257996, Final Test Loss: 0.20297326147556305
# Evaluation time: 0 hours, 0 minutes, 17.69 seconds
