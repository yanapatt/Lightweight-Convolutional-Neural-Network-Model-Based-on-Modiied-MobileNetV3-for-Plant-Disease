# %% [markdown]
# #**Benchmark**

# %% [markdown]
# #**Section 1: Import Important Library**

# %%
import warnings
warnings.filterwarnings('ignore')

from datetime import datetime
import pytz
from time import time

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import font_manager
import seaborn as sns
import itertools
import psutil

import cv2
import shutil
import PIL
import os
from pathlib import Path
import sys

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize, LabelEncoder, LabelBinarizer

import random as rd
import numpy as np
import zipfile

# %%
import tensorflow as tf
os.environ["KERAS_BACKEND"] = "tensorflow"
import keras

# %%
from google.colab import drive
drive.mount('/content/drive')

sys.path.append('/content/drive/MyDrive/projectPlant/Colab')
from my_model import *
from helper_functions import *
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Detail of Python Notebook in Google Colab**

# %%
# !nvidia-smi

import subprocess
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {tf.keras.__version__}")
print("-------------------------------------------------------------")
print(f"Python {sys.version}")
print("-------------------------------------------------------------")

# ตรวจสอบ GPU
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("Running on GPU")
    strategy = tf.distribute.MirroredStrategy()
    print(f"Number of GPUs Available: {len(gpus)}")

    # ดึงข้อมูล GPU Memory
    try:
        result = subprocess.run(
            ['nvidia-smi', '--query-gpu=memory.total', '--format=csv,noheader,nounits'],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )
        gpu_memory = result.stdout.strip().split('\n')
        for idx, mem in enumerate(gpu_memory):
            print(f"GPU {idx}: Total Memory: {int(mem) / 1024:.2f} GB")
    except FileNotFoundError:
        print("nvidia-smi is not available on this system.")
else:
    print("No GPU detected. Running on CPU")
    strategy = tf.distribute.get_strategy()

# แสดงจำนวนอุปกรณ์ที่พร้อมใช้งาน
print("Number of replicas:", strategy.num_replicas_in_sync)
print("-------------------------------------------------------------")

# แสดงจำนวน RAM ทั้งหมด
total_ram = psutil.virtual_memory().total / (1024 ** 3)
print(f"Total RAM of Colab instance: {total_ram:.2f} GB")
print("-------------------------------------------------------------")

# แสดงเวลาปัจจุบันในเขตเวลาไทย
thailand_tz = pytz.timezone('Asia/Bangkok')
current_time = datetime.now(thailand_tz).strftime("%Y-%m-%d %H:%M:%S")
print("Current Time (Thailand):", current_time)
# Out:
# Tue Aug 26 03:32:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Tensorflow version: 2.19.0
# Keras version: 3.10.0
# -------------------------------------------------------------
# Python 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# -------------------------------------------------------------
# Running on GPU
# Number of GPUs Available: 1
# GPU 0: Total Memory: 15.00 GB
# Number of replicas: 1
# -------------------------------------------------------------
# Total RAM of Colab instance: 12.67 GB
# -------------------------------------------------------------
# Current Time (Thailand): 2025-08-26 10:32:06

# %% [markdown]
# **Initialize Setting (Focus First)**

# %%
SEED=42
np.random.seed(SEED)
tf.random.set_seed(SEED)
rd.seed(SEED)
BATCH_SIZE = 64

# %%
root_dir = '/content/drive/MyDrive/projectPlant/'
title = 'PlantVillage Dataset'
dataset_name = 'plantVillageDataset'
dataset_dir = root_dir + dataset_name

# %%
current_dir = os.getcwd()

# %%
zip_filename = 'plantVillage_dataset_raw.zip'
zip_dir = dataset_dir + '/' + zip_filename

with zipfile.ZipFile(zip_dir, 'r') as zip_ref: # แตกไฟล์จาก G-Drive มาที่ Runtime Directory
    zip_ref.extractall(current_dir)
print(f"Unzip complete at {current_dir}")
# Out:
# Unzip complete at /content

# %%
locations = [f"{root_dir}Extra2/Font"]
font_files = font_manager.findSystemFonts(fontpaths=locations)
print(font_files[0])
for file in font_files:
  font_manager.fontManager.addfont(file)
# Out:
# /content/drive/MyDrive/projectPlant/Extra2/Font/OPTITimes-Roman.otf

# %% [markdown]
# #**Section 2: Load Dataset**

# %%
model_name = 'MBNv3Small_Mini'
otmz_name = 'Adam'
seed_num = f"{SEED}"
rounds_num = '1'

# %%
img_dir = root_dir + 'Extra2/' + dataset_name
sample_img_dir = img_dir + '/SampleImages'
img_each_model_dir = img_dir + '/' + model_name + '_' + dataset_name + '_' + otmz_name + '_' + seed_num + '(' + rounds_num + ')'
excel_dir = root_dir + 'DatasetSetting/' + dataset_name + '/' + 'split_data_seed_' + seed_num + '.xlsx'

# %%
os.makedirs(img_dir, exist_ok=True)
os.makedirs(sample_img_dir, exist_ok=True)
os.makedirs(img_each_model_dir, exist_ok=True)

# %% [markdown]
# #**Section 3: Placing data into a Dataframe**

# %% [markdown]
# ##**Convert to dataframe**

# %%
TRAIN_DF, VALID_DF, TEST_DF = to_dataframe_excel(path=excel_dir, sheet_name='Split-Data', mode='single', condition=False, labels_mapping=None)

# %%
print(f"Train Dataframe\n")
print(f"Total images: {len(TRAIN_DF)}")
print(f"Total classes: {TRAIN_DF['Label'].nunique()}")
TRAIN_DF
# Out:
# Train Dataframe
#
# Total images: 13208
# Total classes: 15
#                                                 Filepath  \
# 0      /content/drive/MyDrive/projectPlant/plantVilla...
# 1      /content/drive/MyDrive/projectPlant/plantVilla...
# 2      /content/drive/MyDrive/projectPlant/plantVilla...
# 3      /content/drive/MyDrive/projectPlant/plantVilla...
# 4      /content/drive/MyDrive/projectPlant/plantVilla...
# ...                                                  ...
# 13203  /content/drive/MyDrive/projectPlant/plantVilla...
# 13204  /content/drive/MyDrive/projectPlant/plantVilla...
# 13205  /content/drive/MyDrive/projectPlant/plantVilla...
# 13206  /content/drive/MyDrive/projectPlant/plantVilla...
# 13207  /content/drive/MyDrive/projectPlant/plantVilla...
#
#                                        Label  Original_Index
# 0                      Tomato_Bacterial_spot            5751
# 1                     Pepper__bell___healthy            2155
# 2      Tomato__Tomato_YellowLeaf__Curl_Virus           16158
# 3                      Tomato_Bacterial_spot            5024
# 4                         Tomato_Late_blight            8809
# ...                                      ...             ...
# 13203                       Tomato_Leaf_Mold            9751
# 13204                   Potato___Late_blight            4241
# 13205                    Tomato_Early_blight            7601
# 13206                 Pepper__bell___healthy            2218
# 13207                     Tomato_Late_blight            8915
#
# [13208 rows x 3 columns]

# %%
TRAIN_DF["Filepath"] = TRAIN_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
TRAIN_DF
# Out:
#                                                 Filepath  \
# 0      /content/plantVillageDataset/Tomato_Bacterial_...
# 1      /content/plantVillageDataset/Pepper__bell___he...
# 2      /content/plantVillageDataset/Tomato__Tomato_Ye...
# 3      /content/plantVillageDataset/Tomato_Bacterial_...
# 4      /content/plantVillageDataset/Tomato_Late_bligh...
# ...                                                  ...
# 13203  /content/plantVillageDataset/Tomato_Leaf_Mold/...
# 13204  /content/plantVillageDataset/Potato___Late_bli...
# 13205  /content/plantVillageDataset/Tomato_Early_blig...
# 13206  /content/plantVillageDataset/Pepper__bell___he...
# 13207  /content/plantVillageDataset/Tomato_Late_bligh...
#
#                                        Label  Original_Index
# 0                      Tomato_Bacterial_spot            5751
# 1                     Pepper__bell___healthy            2155
# 2      Tomato__Tomato_YellowLeaf__Curl_Virus           16158
# 3                      Tomato_Bacterial_spot            5024
# 4                         Tomato_Late_blight            8809
# ...                                      ...             ...
# 13203                       Tomato_Leaf_Mold            9751
# 13204                   Potato___Late_blight            4241
# 13205                    Tomato_Early_blight            7601
# 13206                 Pepper__bell___healthy            2218
# 13207                     Tomato_Late_blight            8915
#
# [13208 rows x 3 columns]

# %%
print(f"Validation Dataframe\n")
print(f"Total images: {len(VALID_DF)}")
print(f"Total classes: {VALID_DF['Label'].nunique()}")
VALID_DF
# Out:
# Validation Dataframe
#
# Total images: 3302
# Total classes: 15
#                                                Filepath  \
# 0     /content/drive/MyDrive/projectPlant/plantVilla...
# 1     /content/drive/MyDrive/projectPlant/plantVilla...
# 2     /content/drive/MyDrive/projectPlant/plantVilla...
# 3     /content/drive/MyDrive/projectPlant/plantVilla...
# 4     /content/drive/MyDrive/projectPlant/plantVilla...
# ...                                                 ...
# 3297  /content/drive/MyDrive/projectPlant/plantVilla...
# 3298  /content/drive/MyDrive/projectPlant/plantVilla...
# 3299  /content/drive/MyDrive/projectPlant/plantVilla...
# 3300  /content/drive/MyDrive/projectPlant/plantVilla...
# 3301  /content/drive/MyDrive/projectPlant/plantVilla...
#
#                                             Label  Original_Index
# 0           Tomato__Tomato_YellowLeaf__Curl_Virus           15877
# 1     Tomato_Spider_mites_Two_spotted_spider_mite           13525
# 2                                  Tomato_healthy           19272
# 3           Tomato__Tomato_YellowLeaf__Curl_Virus           16427
# 4                             Tomato__Target_Spot           14005
# ...                                           ...             ...
# 3297                          Tomato__Target_Spot           14105
# 3298                        Tomato_Bacterial_spot            6432
# 3299                Pepper__bell___Bacterial_spot              60
# 3300                             Potato___healthy            4523
# 3301                          Tomato_Early_blight            7347
#
# [3302 rows x 3 columns]

# %%
VALID_DF["Filepath"] = VALID_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
VALID_DF
# Out:
#                                                Filepath  \
# 0     /content/plantVillageDataset/Tomato__Tomato_Ye...
# 1     /content/plantVillageDataset/Tomato_Spider_mit...
# 2     /content/plantVillageDataset/Tomato_healthy/98...
# 3     /content/plantVillageDataset/Tomato__Tomato_Ye...
# 4     /content/plantVillageDataset/Tomato__Target_Sp...
# ...                                                 ...
# 3297  /content/plantVillageDataset/Tomato__Target_Sp...
# 3298  /content/plantVillageDataset/Tomato_Bacterial_...
# 3299  /content/plantVillageDataset/Pepper__bell___Ba...
# 3300  /content/plantVillageDataset/Potato___healthy/...
# 3301  /content/plantVillageDataset/Tomato_Early_blig...
#
#                                             Label  Original_Index
# 0           Tomato__Tomato_YellowLeaf__Curl_Virus           15877
# 1     Tomato_Spider_mites_Two_spotted_spider_mite           13525
# 2                                  Tomato_healthy           19272
# 3           Tomato__Tomato_YellowLeaf__Curl_Virus           16427
# 4                             Tomato__Target_Spot           14005
# ...                                           ...             ...
# 3297                          Tomato__Target_Spot           14105
# 3298                        Tomato_Bacterial_spot            6432
# 3299                Pepper__bell___Bacterial_spot              60
# 3300                             Potato___healthy            4523
# 3301                          Tomato_Early_blight            7347
#
# [3302 rows x 3 columns]

# %%
print(f"Test Dataframe\n")
print(f"Total images: {len(TEST_DF)}")
print(f"Total classes: {TEST_DF['Label'].nunique()}")
TEST_DF
# Out:
# Test Dataframe
#
# Total images: 4128
# Total classes: 15
#                                                Filepath  \
# 0     /content/drive/MyDrive/projectPlant/plantVilla...
# 1     /content/drive/MyDrive/projectPlant/plantVilla...
# 2     /content/drive/MyDrive/projectPlant/plantVilla...
# 3     /content/drive/MyDrive/projectPlant/plantVilla...
# 4     /content/drive/MyDrive/projectPlant/plantVilla...
# ...                                                 ...
# 4123  /content/drive/MyDrive/projectPlant/plantVilla...
# 4124  /content/drive/MyDrive/projectPlant/plantVilla...
# 4125  /content/drive/MyDrive/projectPlant/plantVilla...
# 4126  /content/drive/MyDrive/projectPlant/plantVilla...
# 4127  /content/drive/MyDrive/projectPlant/plantVilla...
#
#                                             Label  Original_Index
# 0                           Potato___Early_blight            2655
# 1     Tomato_Spider_mites_Two_spotted_spider_mite           12257
# 2                              Tomato_Late_blight            8851
# 3     Tomato_Spider_mites_Two_spotted_spider_mite           12831
# 4                              Tomato_Late_blight            9140
# ...                                           ...             ...
# 4123                               Tomato_healthy           19299
# 4124                             Tomato_Leaf_Mold            9885
# 4125                           Tomato_Late_blight            7976
# 4126                        Tomato_Bacterial_spot            5742
# 4127                           Tomato_Late_blight            9024
#
# [4128 rows x 3 columns]

# %%
TEST_DF["Filepath"] = TEST_DF["Filepath"].str.replace(
    "/content/drive/MyDrive/projectPlant/",
    "/content/"
)
TEST_DF
# Out:
#                                                Filepath  \
# 0     /content/plantVillageDataset/Potato___Early_bl...
# 1     /content/plantVillageDataset/Tomato_Spider_mit...
# 2     /content/plantVillageDataset/Tomato_Late_bligh...
# 3     /content/plantVillageDataset/Tomato_Spider_mit...
# 4     /content/plantVillageDataset/Tomato_Late_bligh...
# ...                                                 ...
# 4123  /content/plantVillageDataset/Tomato_healthy/9d...
# 4124  /content/plantVillageDataset/Tomato_Leaf_Mold/...
# 4125  /content/plantVillageDataset/Tomato_Late_bligh...
# 4126  /content/plantVillageDataset/Tomato_Bacterial_...
# 4127  /content/plantVillageDataset/Tomato_Late_bligh...
#
#                                             Label  Original_Index
# 0                           Potato___Early_blight            2655
# 1     Tomato_Spider_mites_Two_spotted_spider_mite           12257
# 2                              Tomato_Late_blight            8851
# 3     Tomato_Spider_mites_Two_spotted_spider_mite           12831
# 4                              Tomato_Late_blight            9140
# ...                                           ...             ...
# 4123                               Tomato_healthy           19299
# 4124                             Tomato_Leaf_Mold            9885
# 4125                           Tomato_Late_blight            7976
# 4126                        Tomato_Bacterial_spot            5742
# 4127                           Tomato_Late_blight            9024
#
# [4128 rows x 3 columns]

# %% [markdown]
# #**Section 4: Data Preparing**

# %%
IMAGE_SIZE = (224, 224)
IMAGE_SHAPE = (224, 224, 3)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=keras.applications.mobilenet_v3.preprocess_input,
    horizontal_flip=True,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    brightness_range=[0.9, 1.1],
    fill_mode='nearest'
)

valid_test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=keras.applications.mobilenet_v3.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe = TRAIN_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed = SEED
)

val_images = valid_test_generator.flow_from_dataframe(
    dataframe = VALID_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed = SEED
)

test_images = valid_test_generator.flow_from_dataframe(
    dataframe = TEST_DF,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = IMAGE_SIZE,
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = False
)
# Out:
# Found 13208 validated image filenames belonging to 15 classes.
# Found 3302 validated image filenames belonging to 15 classes.
# Found 4128 validated image filenames belonging to 15 classes.

# %% [markdown]
# #**Section 5: Preparing the Model**

# %%
checkpoint_path, save_path_h5, save_path_keras, save_path_json, save_path_history, save_path_tensorboard = save_path(otmz_name=otmz_name, dataset_name=dataset_name, rounds=rounds_num, model=model_name, seed=SEED)
print("Recheck save path: \n")
print(f"Checkpoint path: {checkpoint_path}")
print(f"Save path h5: {save_path_h5}")
print(f"Save path keras: {save_path_keras}")
print(f"Save path json: {save_path_json}")
print(f"Save path history: {save_path_history}")
print(f"Save path tensorboard: {save_path_tensorboard}")
# Out:
# Recheck save path:
#
# Checkpoint path: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# Save path h5: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1).h5
# Save path keras: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1).keras
# Save path json: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1).json
# Save path history: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1).csv
# Save path tensorboard: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_tensorboard_logs

# %% [markdown]
# ##**Create Model Callback**

# %%
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_path,
    monitor = 'val_accuracy',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False,
    mode = 'auto'
)

class LearningRateTracker(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        # Access learning rate through learning_rate property
        lr = self.model.optimizer.learning_rate.numpy()  # This will now work correctly
        logs = logs or {}
        logs['lr'] = lr

        if not hasattr(self, 'learning_rates'):
            self.learning_rates = []
        self.learning_rates.append(lr)

# Create the callback instance
lr_tracker = LearningRateTracker()

tensorlog = keras.callbacks.TensorBoard(
    log_dir = save_path_tensorboard,
    histogram_freq = 1,
    write_graph = True,
    write_images = True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor = 'val_loss',
    factor = 0.1,
    patience = 5,
    verbose = 1,
    min_lr = 1e-06
)

# %% [markdown]
# ##**Model Parameters**

# %%
chao_kuay_model = build_model(model_name="MobileNetV3SmallMinimalistic", input_shape=IMAGE_SHAPE, num_classes=len(train_images.class_indices))
chao_kuay_model.compile(
    optimizer = keras.optimizers.Adam(
        learning_rate = 1e-03,
        beta_1 = 0.9,
        beta_2 = 0.999,
        epsilon = 1e-07,
        name = 'Adam'
    ),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
chao_kuay_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_minimalistic_224_1.0_float_no_top_v2.h5
# 2128592/2128592 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 113, 113,  │          0 │ re_lu[0][0]       │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 56, 56,    │        144 │ expanded_conv_de… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 56, 56,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 56, 56,    │        256 │ re_lu_1[0][0]     │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 56, 56,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 56, 56,    │      1,152 │ expanded_conv_pr… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 56, 56,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 57, 57,    │          0 │ re_lu_2[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 28, 28,    │        648 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 28, 28,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 28, 28,    │      1,728 │ re_lu_3[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 28, 28,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 28, 28,    │      2,112 │ expanded_conv_1_… │
# │ (Conv2D)            │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 28, 28,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 28, 28,    │        792 │ re_lu_4[0][0]     │
# │ (DepthwiseConv2D)   │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 28, 28,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 28, 28,    │      2,112 │ re_lu_5[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 28, 28,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 28, 28,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 28, 28,    │      2,304 │ expanded_conv_2_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 28, 28,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 29, 29,    │          0 │ re_lu_6[0][0]     │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 14, 14,    │        864 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 14, 14,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 14, 14,    │          0 │ expanded_conv_3_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 14, 14,    │      3,840 │ re_lu_7[0][0]     │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 14, 14,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 14, 14,    │      9,600 │ expanded_conv_3_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 14, 14,    │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │                     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 14, 14,    │      2,160 │ re_lu_8[0][0]     │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 14, 14,    │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │                     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 14, 14,    │      9,600 │ re_lu_9[0][0]     │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 14, 14,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 14, 14,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 14, 14,    │      9,600 │ expanded_conv_4_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 14, 14,    │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_5_… │
# │                     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 14, 14,    │      2,160 │ re_lu_10[0][0]    │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 14, 14,    │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_5_… │
# │                     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 14, 14,    │      9,600 │ re_lu_11[0][0]    │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 14, 14,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 14, 14,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 14, 14,    │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      1,080 │ re_lu_12[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │      5,760 │ re_lu_13[0][0]    │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        192 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │      6,912 │ expanded_conv_6_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,296 │ re_lu_14[0][0]    │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │      6,912 │ re_lu_15[0][0]    │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        192 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 48)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     13,824 │ expanded_conv_7_… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │                     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 15, 15,    │          0 │ re_lu_16[0][0]    │
# │ (ZeroPadding2D)     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │      2,592 │ expanded_conv_8_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 7, 7, 288) │          0 │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 7, 7, 96)  │     27,648 │ re_lu_17[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 7, 7, 96)  │        384 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 7, 7, 576) │     55,296 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 7, 7, 576) │          0 │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 7, 7, 576) │      5,184 │ re_lu_18[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 7, 7, 576) │          0 │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 7, 7, 96)  │     55,296 │ re_lu_19[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 7, 7, 96)  │        384 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 7, 7, 96)  │          0 │ expanded_conv_8_… │
# │ (Add)               │                   │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 7, 7, 576) │     55,296 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 7, 7, 576) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 7, 7, 576) │      5,184 │ re_lu_20[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 7, 7, 576) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 7, 7, 96)  │     55,296 │ re_lu_21[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 7, 7, 96)  │        384 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_a… │ (None, 7, 7, 96)  │          0 │ expanded_conv_9_… │
# │ (Add)               │                   │            │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 576) │     55,296 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 576) │      2,304 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 7, 7, 576) │          0 │ conv_1_bn[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 576)       │          0 │ re_lu_22[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Predictions (Dense) │ (None, 15)        │      8,655 │ avg_pool[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 449,655 (1.72 MB)
#  Trainable params: 8,655 (33.81 KB)
#  Non-trainable params: 441,000 (1.68 MB)

# %% [markdown]
# #**Section 6: Training the model**

# %%
start_time_training = time()

history = chao_kuay_model.fit(
    x = train_images,
    validation_data = val_images,
    batch_size = BATCH_SIZE,
    callbacks = [model_checkpoint, tensorlog, lr_tracker, reduce_lr],
    epochs = 30,
)

end_time_training = time()
# Out:
# Epoch 1/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 888ms/step - accuracy: 0.4041 - loss: 2.0216
# Epoch 1: val_accuracy improved from -inf to 0.74167, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 219s 989ms/step - accuracy: 0.4050 - loss: 2.0192 - val_accuracy: 0.7417 - val_loss: 0.9063 - learning_rate: 0.0010
# Epoch 2/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.7881 - loss: 0.8475
# Epoch 2: val_accuracy improved from 0.74167 to 0.82495, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 187s 902ms/step - accuracy: 0.7882 - loss: 0.8471 - val_accuracy: 0.8250 - val_loss: 0.6359 - learning_rate: 0.0010
# Epoch 3/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - accuracy: 0.8350 - loss: 0.6258
# Epoch 3: val_accuracy improved from 0.82495 to 0.85736, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 888ms/step - accuracy: 0.8351 - loss: 0.6256 - val_accuracy: 0.8574 - val_loss: 0.5277 - learning_rate: 0.0010
# Epoch 4/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.8619 - loss: 0.5130
# Epoch 4: val_accuracy improved from 0.85736 to 0.86160, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 890ms/step - accuracy: 0.8620 - loss: 0.5129 - val_accuracy: 0.8616 - val_loss: 0.4757 - learning_rate: 0.0010
# Epoch 5/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.8742 - loss: 0.4550
# Epoch 5: val_accuracy improved from 0.86160 to 0.88098, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 182s 879ms/step - accuracy: 0.8742 - loss: 0.4549 - val_accuracy: 0.8810 - val_loss: 0.4325 - learning_rate: 0.0010
# Epoch 6/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.8864 - loss: 0.4198
# Epoch 6: val_accuracy did not improve from 0.88098
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 886ms/step - accuracy: 0.8864 - loss: 0.4197 - val_accuracy: 0.8780 - val_loss: 0.4131 - learning_rate: 0.0010
# Epoch 7/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.8972 - loss: 0.3803
# Epoch 7: val_accuracy improved from 0.88098 to 0.88280, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 202s 890ms/step - accuracy: 0.8972 - loss: 0.3802 - val_accuracy: 0.8828 - val_loss: 0.3868 - learning_rate: 0.0010
# Epoch 8/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - accuracy: 0.8983 - loss: 0.3485
# Epoch 8: val_accuracy improved from 0.88280 to 0.88825, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 183s 886ms/step - accuracy: 0.8984 - loss: 0.3485 - val_accuracy: 0.8882 - val_loss: 0.3712 - learning_rate: 0.0010
# Epoch 9/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.9096 - loss: 0.3338
# Epoch 9: val_accuracy improved from 0.88825 to 0.89067, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 181s 874ms/step - accuracy: 0.9096 - loss: 0.3338 - val_accuracy: 0.8907 - val_loss: 0.3602 - learning_rate: 0.0010
# Epoch 10/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9122 - loss: 0.3156
# Epoch 10: val_accuracy improved from 0.89067 to 0.89431, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 186s 899ms/step - accuracy: 0.9122 - loss: 0.3156 - val_accuracy: 0.8943 - val_loss: 0.3464 - learning_rate: 0.0010
# Epoch 11/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9100 - loss: 0.3077
# Epoch 11: val_accuracy improved from 0.89431 to 0.89491, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 182s 880ms/step - accuracy: 0.9100 - loss: 0.3077 - val_accuracy: 0.8949 - val_loss: 0.3485 - learning_rate: 0.0010
# Epoch 12/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.9109 - loss: 0.2990
# Epoch 12: val_accuracy improved from 0.89491 to 0.90491, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 180s 872ms/step - accuracy: 0.9109 - loss: 0.2990 - val_accuracy: 0.9049 - val_loss: 0.3168 - learning_rate: 0.0010
# Epoch 13/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9220 - loss: 0.2772
# Epoch 13: val_accuracy did not improve from 0.90491
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 181s 872ms/step - accuracy: 0.9220 - loss: 0.2772 - val_accuracy: 0.9034 - val_loss: 0.3175 - learning_rate: 0.0010
# Epoch 14/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 851ms/step - accuracy: 0.9215 - loss: 0.2708
# Epoch 14: val_accuracy improved from 0.90491 to 0.90733, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 183s 887ms/step - accuracy: 0.9215 - loss: 0.2708 - val_accuracy: 0.9073 - val_loss: 0.3069 - learning_rate: 0.0010
# Epoch 15/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9245 - loss: 0.2644
# Epoch 15: val_accuracy did not improve from 0.90733
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 182s 881ms/step - accuracy: 0.9245 - loss: 0.2644 - val_accuracy: 0.9034 - val_loss: 0.3220 - learning_rate: 0.0010
# Epoch 16/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9163 - loss: 0.2684
# Epoch 16: val_accuracy did not improve from 0.90733
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 182s 879ms/step - accuracy: 0.9163 - loss: 0.2684 - val_accuracy: 0.9007 - val_loss: 0.3333 - learning_rate: 0.0010
# Epoch 17/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.9245 - loss: 0.2564
# Epoch 17: val_accuracy did not improve from 0.90733
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 188s 908ms/step - accuracy: 0.9245 - loss: 0.2564 - val_accuracy: 0.9025 - val_loss: 0.3215 - learning_rate: 0.0010
# Epoch 18/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9308 - loss: 0.2415
# Epoch 18: val_accuracy improved from 0.90733 to 0.91036, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 186s 899ms/step - accuracy: 0.9307 - loss: 0.2415 - val_accuracy: 0.9104 - val_loss: 0.3130 - learning_rate: 0.0010
# Epoch 19/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.9321 - loss: 0.2346
# Epoch 19: val_accuracy did not improve from 0.91036
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 182s 881ms/step - accuracy: 0.9321 - loss: 0.2346 - val_accuracy: 0.8988 - val_loss: 0.3291 - learning_rate: 0.0010
# Epoch 20/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.9352 - loss: 0.2211
# Epoch 20: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 186s 898ms/step - accuracy: 0.9352 - loss: 0.2212 - val_accuracy: 0.9067 - val_loss: 0.3071 - learning_rate: 1.0000e-04
# Epoch 21/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.9343 - loss: 0.2236
# Epoch 21: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 889ms/step - accuracy: 0.9343 - loss: 0.2236 - val_accuracy: 0.9076 - val_loss: 0.3030 - learning_rate: 1.0000e-04
# Epoch 22/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - accuracy: 0.9304 - loss: 0.2370
# Epoch 22: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 888ms/step - accuracy: 0.9304 - loss: 0.2370 - val_accuracy: 0.9091 - val_loss: 0.3038 - learning_rate: 1.0000e-04
# Epoch 23/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 849ms/step - accuracy: 0.9332 - loss: 0.2333
# Epoch 23: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 889ms/step - accuracy: 0.9332 - loss: 0.2333 - val_accuracy: 0.9070 - val_loss: 0.3063 - learning_rate: 1.0000e-04
# Epoch 24/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.9336 - loss: 0.2276
# Epoch 24: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 888ms/step - accuracy: 0.9336 - loss: 0.2276 - val_accuracy: 0.9070 - val_loss: 0.3053 - learning_rate: 1.0000e-04
# Epoch 25/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9315 - loss: 0.2250
# Epoch 25: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 182s 880ms/step - accuracy: 0.9315 - loss: 0.2250 - val_accuracy: 0.9082 - val_loss: 0.3034 - learning_rate: 1.0000e-04
# Epoch 26/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.9358 - loss: 0.2248
# Epoch 26: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 889ms/step - accuracy: 0.9358 - loss: 0.2248 - val_accuracy: 0.9094 - val_loss: 0.2995 - learning_rate: 1.0000e-04
# Epoch 27/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9369 - loss: 0.2236
# Epoch 27: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 183s 880ms/step - accuracy: 0.9369 - loss: 0.2236 - val_accuracy: 0.9094 - val_loss: 0.3014 - learning_rate: 1.0000e-04
# Epoch 28/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - accuracy: 0.9305 - loss: 0.2328
# Epoch 28: val_accuracy did not improve from 0.91036
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 184s 889ms/step - accuracy: 0.9305 - loss: 0.2327 - val_accuracy: 0.9064 - val_loss: 0.3048 - learning_rate: 1.0000e-04
# Epoch 29/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 859ms/step - accuracy: 0.9404 - loss: 0.2187
# Epoch 29: val_accuracy improved from 0.91036 to 0.91157, saving model to /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1)_best.keras
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 185s 896ms/step - accuracy: 0.9404 - loss: 0.2187 - val_accuracy: 0.9116 - val_loss: 0.2944 - learning_rate: 1.0000e-04
# Epoch 30/30
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9375 - loss: 0.2265
# Epoch 30: val_accuracy did not improve from 0.91157
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 202s 896ms/step - accuracy: 0.9375 - loss: 0.2264 - val_accuracy: 0.9098 - val_loss: 0.3012 - learning_rate: 1.0000e-04

# %%
history_dict = history.history
print(f"History: {history_dict}")
# Out:
# History: {'accuracy': [0.5896426439285278, 0.8055723905563354, 0.8452453017234802, 0.8662174344062805, 0.8791641592979431, 0.8877195715904236, 0.8977892398834229, 0.9002876877784729, 0.9064960479736328, 0.9104330539703369, 0.9133101105690002, 0.913840115070343, 0.9226226806640625, 0.9221683740615845, 0.9238340258598328, 0.9211841225624084, 0.923531174659729, 0.9259539842605591, 0.9304209351539612, 0.9323137402534485, 0.9327680468559265, 0.9340550899505615, 0.9332979917526245, 0.9354936480522156, 0.9314051866531372, 0.9356450438499451, 0.933676540851593, 0.9332979917526245, 0.9357208013534546, 0.9367807507514954], 'loss': [1.5131546258926392, 0.7667273283004761, 0.5891227126121521, 0.4978264272212982, 0.4429788291454315, 0.4048469364643097, 0.3716653883457184, 0.34597912430763245, 0.3315209448337555, 0.31473037600517273, 0.3021529018878937, 0.29426413774490356, 0.2812492549419403, 0.26955193281173706, 0.2652290165424347, 0.25865983963012695, 0.25111138820648193, 0.24534954130649567, 0.2369726598262787, 0.22746872901916504, 0.22785191237926483, 0.22941529750823975, 0.22778433561325073, 0.22441422939300537, 0.22677844762802124, 0.22235806286334991, 0.2263619303703308, 0.22729873657226562, 0.22308188676834106, 0.222941592335701], 'val_accuracy': [0.7416717410087585, 0.8249545693397522, 0.8573591709136963, 0.8615990281105042, 0.8809812068939209, 0.8779527544975281, 0.8827983140945435, 0.8882495164871216, 0.8906723260879517, 0.894306480884552, 0.8949121832847595, 0.9049060940742493, 0.9033918976783752, 0.9073289036750793, 0.9033918976783752, 0.9006662368774414, 0.902483344078064, 0.9103573560714722, 0.8988491892814636, 0.9067232012748718, 0.9076317548751831, 0.9091459512710571, 0.9070260524749756, 0.9070260524749756, 0.9082374572753906, 0.9094488024711609, 0.9094488024711609, 0.9064203500747681, 0.9115687608718872, 0.9097516536712646], 'val_loss': [0.9062902927398682, 0.6359002590179443, 0.5276750326156616, 0.4756826162338257, 0.43248069286346436, 0.4130658209323883, 0.3867672383785248, 0.3712008595466614, 0.3602299690246582, 0.34642013907432556, 0.3484974801540375, 0.3167888820171356, 0.3175323009490967, 0.3068588078022003, 0.3220486640930176, 0.3333267271518707, 0.32148972153663635, 0.3130066990852356, 0.32910123467445374, 0.30710655450820923, 0.3029947876930237, 0.30382397770881653, 0.30629274249076843, 0.30533361434936523, 0.3033980429172516, 0.29945194721221924, 0.3013967275619507, 0.304757684469223, 0.2943902015686035, 0.30122682452201843], 'learning_rate': [0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513, 0.00010000000474974513]}

# %%
training_time = end_time_training - start_time_training
hours, remainder = divmod(training_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Training time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Training time: 1 hours, 33 minutes, 2.84 seconds

# %% [markdown]
# ##**Save the model**

# %%
save_epoch_history(history, save_path_history)
# Out:
# History has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1).csv

# %%
save_model(chao_kuay_model, save_path_h5, save_path_keras, save_path_json)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1).keras
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1).h5
# Model has been saved to: /content/drive/MyDrive/projectPlant/modelTest2/MBNv3Small_Mini/plantVillageDataset_42(1)/Adam/MBNv3Small_Mini_plantVillageDataset_Adam_42(1).json

# %% [markdown]
# #**Section 7: Model Evaluation**

# %%
start_time_evaluate = time()
test_acc = chao_kuay_model.evaluate(test_images, verbose=1)
print(f"Final Test Accuracy: {test_acc[1]}, Final Test Loss: {test_acc[0]}")
end_time_evaluate = time()
evaluate_time = end_time_evaluate - start_time_evaluate
hours, remainder = divmod(evaluate_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Evaluation time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 16s 252ms/step - accuracy: 0.9058 - loss: 0.3022
# Final Test Accuracy: 0.9091569781303406, Final Test Loss: 0.2918702960014343
# Evaluation time: 0 hours, 0 minutes, 20.65 seconds

# %%
tr_plot_no_best_epoch(history, 0, paths=img_each_model_dir)

# %%
lr_plot(lr_tracker, history, paths=img_each_model_dir)

# %% [markdown]
# #**Section 8: Making predictions on the Predict Data**

# %%
# พยากรณ์ผลลัพธ์จากโมเดล
predictions = chao_kuay_model.predict(test_images)
# แปลงผลลัพธ์เป็น index ของ class ที่มีค่าความน่าจะเป็นสูงสุด
predicted_indices = np.argmax(predictions, axis=1)
# ดึงข้อมูล mapping ระหว่าง index กับ class name จาก training set
class_index_mapping = train_images.class_indices
# สลับ key กับ value เพื่อแปลงจาก index กลับไปเป็นชื่อ class
index_to_class = dict((v, k) for k, v in class_index_mapping.items())
# แปลง predicted index ให้เป็นชื่อ class ที่เกี่ยวข้อง
predicted_classes = [index_to_class[index] for index in predicted_indices]
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step

# %% [markdown]
# ##**Misclass Predicted**

# %%
incorrect_index = [i for i in range(len(TEST_DF)) if TEST_DF.Label.iloc[i] != predicted_classes[i]]

# สร้าง DataFrame ใหม่ที่มีเฉพาะแถวที่ทำนายผิด
misclassified_df = TEST_DF.iloc[incorrect_index].copy()
# เพิ่มคอลัมน์ Predicted Label ลงใน DataFrame
misclassified_df['Predicted Label'] = [predicted_classes[i] for i in incorrect_index]  # เปลี่ยนชื่อให้ตรงกับที่ต้องการ
# เลือกคอลัมน์ Filepath, Label (True Label), และ Predicted Label
result_misclass_df = misclassified_df[['Filepath', 'Label', 'Predicted Label']]
# เปลี่ยนชื่อคอลัมน์ Label เป็น True Label
result_misclass_df = result_misclass_df.rename(columns={'Label': 'True Label'})

print("Misclassified Dataframe Detail:")
result_misclass_df
# Out:
# Misclassified Dataframe Detail:
#                                                Filepath  \
# 4     /content/plantVillageDataset/Tomato_Late_bligh...
# 24    /content/plantVillageDataset/Tomato_Early_blig...
# 35    /content/plantVillageDataset/Tomato__Tomato_mo...
# 51    /content/plantVillageDataset/Tomato__Tomato_Ye...
# 54    /content/plantVillageDataset/Potato___Early_bl...
# ...                                                 ...
# 4095  /content/plantVillageDataset/Tomato__Target_Sp...
# 4105  /content/plantVillageDataset/Tomato_Bacterial_...
# 4113  /content/plantVillageDataset/Tomato__Target_Sp...
# 4114  /content/plantVillageDataset/Tomato_Bacterial_...
# 4116  /content/plantVillageDataset/Tomato_Late_bligh...
#
#                                  True Label  \
# 4                        Tomato_Late_blight
# 24                      Tomato_Early_blight
# 35              Tomato__Tomato_mosaic_virus
# 51    Tomato__Tomato_YellowLeaf__Curl_Virus
# 54                    Potato___Early_blight
# ...                                     ...
# 4095                    Tomato__Target_Spot
# 4105                  Tomato_Bacterial_spot
# 4113                    Tomato__Target_Spot
# 4114                  Tomato_Bacterial_spot
# 4116                     Tomato_Late_blight
#
#                                   Predicted Label
# 4                                  Tomato_healthy
# 24                            Tomato__Target_Spot
# 35    Tomato_Spider_mites_Two_spotted_spider_mite
# 51                             Tomato_Late_blight
# 54                  Pepper__bell___Bacterial_spot
# ...                                           ...
# 4095                               Tomato_healthy
# 4105                    Tomato_Septoria_leaf_spot
# 4113  Tomato_Spider_mites_Two_spotted_spider_mite
# 4114                          Tomato__Target_Spot
# 4116                    Tomato_Septoria_leaf_spot
#
# [375 rows x 3 columns]

# %%
y_test = list(TEST_DF.Label)
report = classification_report(y_test, predicted_classes, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df
# Out:
#                                              precision    recall  f1-score  \
# Pepper__bell___Bacterial_spot                 0.925234  0.994975  0.958838
# Pepper__bell___healthy                        1.000000  0.976351  0.988034
# Potato___Early_blight                         0.960976  0.985000  0.972840
# Potato___Late_blight                          0.973118  0.905000  0.937824
# Potato___healthy                              0.928571  0.866667  0.896552
# Tomato_Bacterial_spot                         0.977591  0.819249  0.891443
# Tomato_Early_blight                           0.942623  0.575000  0.714286
# Tomato_Late_blight                            0.904393  0.916230  0.910273
# Tomato_Leaf_Mold                              0.855769  0.936842  0.894472
# Tomato_Septoria_leaf_spot                     0.835052  0.915254  0.873315
# Tomato_Spider_mites_Two_spotted_spider_mite   0.832891  0.937313  0.882022
# Tomato__Target_Spot                           0.726415  0.822064  0.771285
# Tomato__Tomato_YellowLeaf__Curl_Virus         0.990369  0.961059  0.975494
# Tomato__Tomato_mosaic_virus                   0.957143  0.893333  0.924138
# Tomato_healthy                                0.890449  0.996855  0.940653
# accuracy                                      0.909157  0.909157  0.909157
# macro avg                                     0.913373  0.900080  0.902098
# weighted avg                                  0.915059  0.909157  0.908103
#
#                                                  support
# Pepper__bell___Bacterial_spot                 199.000000
# Pepper__bell___healthy                        296.000000
# Potato___Early_blight                         200.000000
# Potato___Late_blight                          200.000000
# Potato___healthy                               30.000000
# Tomato_Bacterial_spot                         426.000000
# Tomato_Early_blight                           200.000000
# Tomato_Late_blight                            382.000000
# Tomato_Leaf_Mold                              190.000000
# Tomato_Septoria_leaf_spot                     354.000000
# Tomato_Spider_mites_Two_spotted_spider_mite   335.000000
# Tomato__Target_Spot                           281.000000
# Tomato__Tomato_YellowLeaf__Curl_Virus         642.000000
# Tomato__Tomato_mosaic_virus                    75.000000
# Tomato_healthy                                318.000000
# accuracy                                        0.909157
# macro avg                                    4128.000000
# weighted avg                                 4128.000000

# %% [markdown]
# ##**Plot ROC Curve**

# %%
plot_roc_curve(y_test, predictions, paths=img_each_model_dir)

# %% [markdown]
# ##**Plot Confusion Matrix**

# %%
target_names = list(index_to_class.values())
cm = confusion_matrix(y_test, predicted_classes)
plot_confusion_matrix(cm=cm, target_names=target_names, title='Confusion Matrix', fontsize=16, paths=img_each_model_dir)

# %%
plot_confusion_matrix(cm=cm, target_names=target_names, title='Confusion Matrix Normalize', normalize = True, fontsize=16, paths=img_each_model_dir)

# %% [markdown]
# ##**Load Model Test**

# %%
load_model = keras.saving.load_model(save_path_keras)

# %%
start_time_evaluate = time()
test_acc_load = load_model.evaluate(test_images, verbose=1)
print(f"Final Test Accuracy: {test_acc_load[1]}, Final Test Loss: {test_acc_load[0]}")
end_time_evaluate = time()
evaluate_time = end_time_evaluate - start_time_evaluate
hours, remainder = divmod(evaluate_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Evaluation time: {int(hours)} hours, {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 14s 144ms/step - accuracy: 0.9058 - loss: 0.3022
# Final Test Accuracy: 0.9091569781303406, Final Test Loss: 0.2918702960014343
# Evaluation time: 0 hours, 0 minutes, 22.77 seconds
